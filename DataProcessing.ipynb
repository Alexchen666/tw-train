# %% [markdown]
# # 台鐵車站的資料分析與視覺化 Part 2. 資料清理

# %% [markdown]
# 爬蟲的資料很髒，因此要花費大把的心力來處理，先匯入所需套件

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import json
import re

# %%
df_wiki = pd.read_json('stationwiki.json')
df_info = pd.read_json('stationinfo.json')

# %% [markdown]
# 為了方便，把兩張表合併，當時在爬取各車站時，有故意用爬取路線時，車站的名字，這樣可以幫助合併不會出錯

# %%
df_info = df_info.merge(df_wiki, on='Station')

# %% [markdown]
# 現在的資料長這樣：

# %%
df_info.head()
# Out:
#     Station    Code Distance Level  \
# 0  瑞芳（ㄖㄈ）\n  7360\n    0.0\n    一等
# 1  瑞芳（ㄖㄈ）\n  7360\n    0.0\n    一等
# 2  瑞芳（ㄖㄈ）\n  7360\n    8.9\n  一等\n
# 3  瑞芳（ㄖㄈ）\n  7360\n    8.9\n  一等\n
# 4     海科館\n  7361\n    4.2\n    招呼
#
#                                          Link       Open      Line
# 0           /wiki/%E7%91%9E%E8%8A%B3%E7%AB%99  1919年5月5日   宜蘭線、深澳線
# 1           /wiki/%E7%91%9E%E8%8A%B3%E7%AB%99  1919年5月5日   宜蘭線、深澳線
# 2  /wiki/%E7%91%9E%E8%8A%B3%E8%BB%8A%E7%AB%99  1919年5月5日   宜蘭線、深澳線
# 3  /wiki/%E7%91%9E%E8%8A%B3%E8%BB%8A%E7%AB%99  1919年5月5日   宜蘭線、深澳線
# 4  /wiki/%E6%B5%B7%E7%A7%91%E9%A4%A8%E7%AB%99  2014年1月9日       深澳線

# %% [markdown]
# 來統整一下，看了前5筆資料後，目前有的問題：
# 1. 重複欄位(如第0筆到第3筆資料)：會這樣的原因是因為一個車站會出現在不只一條路線上
# 2. 中文車站名稱有內部使用的注音符號代碼與換行字元，這些都是我不要的
# 3. 車站代碼、距離、等級有換行字元
#
# 但我不相信問題這麼少，尤其是啟用日期，當時明明有看到很複雜的資料。先放著好了，一步一步來。

# %% [markdown]
# ## 1. 第一階段整理(解決問題2&3)

# %% [markdown]
# 問題1我想要留到後面再來處理

# %%
df_info['Station'] = df_info.Station.str.replace('\n','')

# %%
df_info['Station'] = df_info.Station.str.replace('\（(.+)\）','', regex=True)

# %%
df_info['Code'] = df_info.Code.str.replace('\n','')

# %%
df_info['Distance'] = df_info.Distance.str.replace('\n','')

# %%
df_info['Level'] = df_info.Level.str.replace('\n','')

# %% [markdown]
# 以上就解決掉2&3了

# %% [markdown]
# ## 2. 與車站基本資料合併&解決問題1

# %% [markdown]
# 我想要把車站的資料全部放在一起，這樣比較方便瀏覽

# %%
df_basic = pd.read_json('StationBasic.json', dtype=False) #加False是為了讓stationCode不會被轉換成int

# %%
df_basic.stationCode
# Out:
# 0      0900
# 1      0910
# 2      0920
# 3      0930
# 4      0940
#        ...
# 237    7360
# 238    7361
# 239    7362
# 240    7380
# 241    7390
# Name: stationCode, Length: 242, dtype: object

# %% [markdown]
# 後來想想，因為我們爬取到的資料是"相對"距離，感覺不太好用，所以捨棄。此時我要來處理重複資料了，若用整筆資料完全重複才移除有點不適合，以剛剛看到的瑞芳站為例，前2筆跟後2筆資料的連結是不一樣的，但其實他們都導向同一個頁面，因此我決定只要車站名稱重複就移除。

# %%
df_info.drop('Distance', axis=1, inplace=True)
df_info.drop_duplicates(subset='Station', inplace=True)

# %% [markdown]
# 可以看到我們爬取到的資料筆數筆車站基本資料集的資料還多，這是因為維基百科中，會列出一些目前尚未完工的車站，因此筆數會有出入。

# %%
print(len(df_basic), len(df_info))
# Out:
# 242 260

# %%
df_station = df_basic.merge(df_info, left_on='stationCode', right_on='Code', how='inner')

# %%
df_station.shape
# Out:
# (240, 15)

# %% [markdown]
# 我使用inner join，只取兩邊都有的編碼，這樣才符合我的預期。會發現資料少了兩筆，稍微檢查一下：

# %%
for i in df_basic.stationCode:
    if i not in list(df_info.Code):
        print(df_basic[df_basic.stationCode == i]['stationName'])
# Out:
# 11    臺北-環島
# Name: stationName, dtype: object
# 169    潮州基地
# Name: stationName, dtype: object

# %% [markdown]
# 這兩筆沒有在我們爬取的資料中非常合理，同理我也回去確認了爬取資料中沒有被合併進來的有哪些，正如前所述，都是尚未完工啟用的車站

# %% [markdown]
# 但這兩張表合併後有不少重複欄位，我決定要先來處理一下

# %%
df_station[df_station.stationName != df_station.Station]
# Out:
#     stationCode stationName   stationEName name          ename  \
# 57         2210         臺中港  Taichung Port  臺中港  Taichung Port
# 131        4340         新左營     Xinzuoying  新左營     Xinzuoying
# 197        7030          新城       Xincheng   新城       Xincheng
#
#           stationAddrTw                                      stationAddrEn  \
# 57     臺中市清水區頂湳里甲南路 2 號   No. 2, Jianan Rd., Qingshui Dist., Taichung City
# 131   高雄市左營區尾北里站前北路 1 號  No. 1, Zhanqian N. Rd., Zuoying Dist., Kaohsiu...
# 197  花蓮縣新城鄉新城村新興一路 73 號  No. 73, Xinxing 1st Rd., Xincheng Township, Hu...
#
#       stationTel                 gps  Station  Code Level  \
# 57   04-26225374  24.30441 120.60231      台中港  2210    二等
# 131   07-5887825  22.68721 120.30721     新左營   4340    一等
# 197   03-8611237  24.12761 121.64103  新城(太魯閣)  7030    二等
#
#                                                   Link         Open       Line
# 57   /wiki/%E5%8F%B0%E4%B8%AD%E6%B8%AF%E8%BB%8A%E7%...  1922年10月11日   海岸線、台中港線
# 131  /wiki/%E6%96%B0%E5%B7%A6%E7%87%9F%E8%BB%8A%E7%...   2006年12月1日        縱貫線
# 197  /wiki/%E6%96%B0%E5%9F%8E%EF%BC%88%E5%A4%AA%E9%...   1975年7月26日        北迴線

# %%
df_station.drop('Station', axis=1, inplace=True)

# %%
df_station[df_station.stationName != df_station.name]
# Out:
# Empty DataFrame
# Columns: [stationCode, stationName, stationEName, name, ename, stationAddrTw, stationAddrEn, stationTel, gps, Code, Level, Link, Open, Line]
# Index: []

# %%
df_station.drop('name', axis=1, inplace=True)

# %%
df_station[df_station.stationEName != df_station.ename]
# Out:
# Empty DataFrame
# Columns: [stationCode, stationName, stationEName, ename, stationAddrTw, stationAddrEn, stationTel, gps, Code, Level, Link, Open, Line]
# Index: []

# %%
df_station.drop('ename', axis=1, inplace=True)

# %%
df_station.drop('Code', axis=1, inplace=True)

# %% [markdown]
# 以上就把所有冗冗的欄位都拿掉了，在拿掉之前，我有先確認那些欄位的差異之處，才敢放心拿掉

# %% [markdown]
# ## 3. 第二階段整理

# %% [markdown]
# 前面的整理只是暖暖身而已！這邊才是真正麻煩的地方！
#
# 我處理的多半是數值資料，文字資料相對少碰。原則上，"仔細觀察"仍是最重要的原則，找出這些問題的規律，並且一步一步嘗試，直到他變得非常乾淨。

# %% [markdown]
# 先來看看路線欄位有多髒：

# %%
list(df_station.Line)
# Out:
# [' 縱貫線 基隆捷運（規劃中）',
#  ' 縱貫線',
#  ' 縱貫線、宜蘭線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線\xa0民生汐止線(規劃中)基隆捷運線(規劃中)',
#  ' 臺灣鐵路縱貫線  北宜直線鐵路（規劃中） 基隆捷運（規劃中） 臺灣高鐵 板南線',
#  ' 臺灣鐵路縱貫線\xa0松山新店線 環狀線（規劃中）',
#  ' 臺鐵縱貫線 臺灣高鐵 \xa0淡水信義線  板南線 \xa0機場線',
#  ' 縱貫線',
#  ' 臺灣鐵路縱貫線 臺灣高鐵 板南線（板橋線） 環狀線',
#  '縱貫線\xa0█\xa0泰山板橋輕軌',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線 三鶯線（興建中）三鶯纜車（全案暫緩）',
#  ' 縱貫線 綠線（興建中） 棕線（規劃中）',
#  ' 縱貫線',
#  ' 縱貫線 機場線（興建中）',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線、內灣線',
#  ' 內灣線',
#  ' 內灣線',
#  '內灣線、六家線',
#  '六家線',
#  ' 內灣線',
#  ' 內灣線',
#  ' 內灣線',
#  ' 內灣線',
#  ' 內灣線',
#  ' 內灣線',
#  ' 內灣線',
#  ' 內灣線',
#  ' 縱貫線、內灣線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線、臺中線、海岸線',
#  ' 海岸線',
#  ' 海岸線',
#  ' 海岸線',
#  ' 海岸線',
#  ' 海岸線',
#  ' 海岸線',
#  ' 海岸線',
#  ' 海岸線',
#  ' 海岸線',
#  ' 海岸線',
#  ' 海岸線、台中港線',
#  ' 海岸線',
#  ' 海岸線 \xa0藍線（綜合規劃由交通部審核中）',
#  ' 海岸線',
#  ' 海岸線',
#  ' 海岸線、成追線',
#  ' 臺中線',
#  ' 臺中線',
#  ' 臺中線',
#  ' 臺中線',
#  ' 臺中線',
#  ' 臺中線、舊山線',
#  ' 臺中線',
#  ' 臺中線',
#  ' 臺中線',
#  ' 臺中線',
#  ' 臺中線',
#  ' 臺中線',
#  ' 臺中線',
#  ' 臺中線',
#  ' 臺中線',
#  ' 臺中線',
#  ' 臺中線',
#  ' 臺中線',
#  ' 臺中線',
#  ' 臺中線',
#  ' 臺中線、成追線',
#  ' 臺中線海岸線縱貫線南段',
#  ' 縱貫線南段',
#  ' 縱貫線南段',
#  ' 縱貫線南段',
#  ' 縱貫線南段',
#  ' 縱貫線南段\n',
#  ' 縱貫線南段',
#  ' 縱貫線南段、集集線',
#  ' 集集線',
#  ' 集集線',
#  ' 集集線',
#  ' 集集線',
#  ' 集集線',
#  ' 集集線',
#  ' 縱貫線南段',
#  ' 縱貫線南段',
#  ' 縱貫線南段',
#  ' 縱貫線南段',
#  ' 縱貫線南段',
#  ' 縱貫線南段',
#  ' 縱貫線南段',
#  ' 縱貫線南段',
#  ' 縱貫線 阿里山線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線█\xa0捷運：臺南捷運綠線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線、沙崙線',
#  '沙崙線',
#  '沙崙線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線 紅線',
#  '縱貫線 紅線',
#  ' 縱貫線',
#  '縱貫線',
#  ' 縱貫線',
#  ' 縱貫線',
#  ' 縱貫線  環狀輕軌',
#  ' 縱貫線 環狀輕軌',
#  ' 縱貫線',
#  '屏東線<南/北>縱貫線、 紅線',
#  ' 屏東線 黃線',
#  '屏東線 環狀輕軌',
#  ' 屏東線 黃線',
#  ' 屏東線',
#  ' 屏東線',
#  ' 屏東線',
#  ' 屏東線',
#  ' 屏東線',
#  ' 屏東線',
#  ' 屏東線',
#  ' 屏東線',
#  ' 屏東線',
#  ' 屏東線',
#  ' 屏東線',
#  ' 屏東線',
#  ' 屏東線、東港線 紅線林園東港線',
#  ' 屏東線',
#  ' 屏東線',
#  ' 屏東線',
#  ' 南迴線<南/北>屏東線',
#  ' 南迴線',
#  ' 南迴線 恆春線（規劃中）',
#  ' 南迴線',
#  ' 南迴線',
#  ' 南迴線',
#  ' 南迴線',
#  ' 南迴線',
#  ' 南迴線',
#  ' 南迴線',
#  ' 南迴線',
#  '南迴線<南/北>臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線',
#  ' 臺東線 <南/北>北迴線',
#  ' 北迴線、花蓮臨港線',
#  ' 北迴線',
#  ' 北迴線',
#  ' 北迴線',
#  ' 北迴線',
#  ' 北迴線',
#  ' 北迴線',
#  ' 北迴線',
#  ' 北迴線',
#  ' 北迴線',
#  ' 北迴線',
#  ' 宜蘭線',
#  ' 宜蘭線、北迴線',
#  ' 宜蘭線',
#  ' 宜蘭線',
#  ' 宜蘭線',
#  ' 宜蘭線',
#  ' 宜蘭線',
#  ' 宜蘭線',
#  ' 宜蘭線',
#  ' 宜蘭線',
#  ' 宜蘭線',
#  ' 宜蘭線',
#  ' 宜蘭線',
#  ' 宜蘭線',
#  ' 宜蘭線',
#  ' 宜蘭線',
#  ' 宜蘭線',
#  ' 宜蘭線',
#  ' 宜蘭線',
#  ' 宜蘭線',
#  ' 宜蘭線',
#  ' 宜蘭線、平溪線',
#  ' 平溪線',
#  ' 平溪線',
#  ' 平溪線',
#  ' 平溪線',
#  ' 平溪線',
#  ' 平溪線',
#  ' 宜蘭線',
#  ' 宜蘭線、深澳線',
#  ' 深澳線',
#  ' 深澳線',
#  ' 宜蘭線',
#  ' 宜蘭線']

# %% [markdown]
# 統整一下目前有的問題：
# 1. 文字前有空格
# 2. 有\xa0、█等無關訊息
# 3. 有些路線用空格分隔，有些用頓號，沒有統一
# 4. 我不想要有<...>這樣的東西
#
# 下面的程式碼直接解決上述問題，這就是我喜歡re還有python的地方

# %%
df_station['Line'] = df_station.Line.str.strip().replace('\█','', regex=True).replace('\s+', '、',regex=True)\
    .replace('\<(.+)\>','、', regex=True).replace('\、\、','、', regex=True)

# %% [markdown]
# 但還是會遇到一兩個沒有規則的例外，就當個案處理吧！其實這裡可以不用取代，直接用新的值就好，但有點用上癮了XD

# %%
df_station['Line'] = df_station.Line.str.replace('縱貫線\、民生汐止線\(規劃中\)基隆捷運線\(規劃中\)', 
'縱貫線、民生汐止線（規劃中）、基隆捷運線（規劃中）', regex=True).replace('縱貫線\、三鶯線\（興建中\）三鶯纜車\（全案暫緩\）', '縱貫線、三鶯線（興建中）、三鶯纜車（全案暫緩）', regex=True).replace('臺中線海岸線縱貫線南段', '臺中線海岸線、縱貫線南段', regex=True).replace('捷運\：臺南捷運綠線', '臺南捷運綠線', regex=True)

# %%
list(df_station.Line)
# Out:
# ['縱貫線、基隆捷運（規劃中）',
#  '縱貫線',
#  '縱貫線、宜蘭線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線、民生汐止線(規劃中)基隆捷運線(規劃中)',
#  '臺灣鐵路縱貫線、北宜直線鐵路（規劃中）、基隆捷運（規劃中）、臺灣高鐵、板南線',
#  '臺灣鐵路縱貫線、松山新店線、環狀線（規劃中）',
#  '臺鐵縱貫線、臺灣高鐵、淡水信義線、板南線、機場線',
#  '縱貫線',
#  '臺灣鐵路縱貫線、臺灣高鐵、板南線（板橋線）、環狀線',
#  '縱貫線、泰山板橋輕軌',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線、三鶯線（興建中）三鶯纜車（全案暫緩）',
#  '縱貫線、綠線（興建中）、棕線（規劃中）',
#  '縱貫線',
#  '縱貫線、機場線（興建中）',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線、內灣線',
#  '內灣線',
#  '內灣線',
#  '內灣線、六家線',
#  '六家線',
#  '內灣線',
#  '內灣線',
#  '內灣線',
#  '內灣線',
#  '內灣線',
#  '內灣線',
#  '內灣線',
#  '內灣線',
#  '縱貫線、內灣線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線、臺中線、海岸線',
#  '海岸線',
#  '海岸線',
#  '海岸線',
#  '海岸線',
#  '海岸線',
#  '海岸線',
#  '海岸線',
#  '海岸線',
#  '海岸線',
#  '海岸線',
#  '海岸線、台中港線',
#  '海岸線',
#  '海岸線、藍線（綜合規劃由交通部審核中）',
#  '海岸線',
#  '海岸線',
#  '海岸線、成追線',
#  '臺中線',
#  '臺中線',
#  '臺中線',
#  '臺中線',
#  '臺中線',
#  '臺中線、舊山線',
#  '臺中線',
#  '臺中線',
#  '臺中線',
#  '臺中線',
#  '臺中線',
#  '臺中線',
#  '臺中線',
#  '臺中線',
#  '臺中線',
#  '臺中線',
#  '臺中線',
#  '臺中線',
#  '臺中線',
#  '臺中線',
#  '臺中線、成追線',
#  '臺中線海岸線縱貫線南段',
#  '縱貫線南段',
#  '縱貫線南段',
#  '縱貫線南段',
#  '縱貫線南段',
#  '縱貫線南段',
#  '縱貫線南段',
#  '縱貫線南段、集集線',
#  '集集線',
#  '集集線',
#  '集集線',
#  '集集線',
#  '集集線',
#  '集集線',
#  '縱貫線南段',
#  '縱貫線南段',
#  '縱貫線南段',
#  '縱貫線南段',
#  '縱貫線南段',
#  '縱貫線南段',
#  '縱貫線南段',
#  '縱貫線南段',
#  '縱貫線、阿里山線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線、捷運：臺南捷運綠線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線、沙崙線',
#  '沙崙線',
#  '沙崙線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線、紅線',
#  '縱貫線、紅線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線',
#  '縱貫線、環狀輕軌',
#  '縱貫線、環狀輕軌',
#  '縱貫線',
#  '屏東線、縱貫線、紅線',
#  '屏東線、黃線',
#  '屏東線、環狀輕軌',
#  '屏東線、黃線',
#  '屏東線',
#  '屏東線',
#  '屏東線',
#  '屏東線',
#  '屏東線',
#  '屏東線',
#  '屏東線',
#  '屏東線',
#  '屏東線',
#  '屏東線',
#  '屏東線',
#  '屏東線',
#  '屏東線、東港線、紅線林園東港線',
#  '屏東線',
#  '屏東線',
#  '屏東線',
#  '南迴線、屏東線',
#  '南迴線',
#  '南迴線、恆春線（規劃中）',
#  '南迴線',
#  '南迴線',
#  '南迴線',
#  '南迴線',
#  '南迴線',
#  '南迴線',
#  '南迴線',
#  '南迴線',
#  '南迴線、臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線',
#  '臺東線、北迴線',
#  '北迴線、花蓮臨港線',
#  '北迴線',
#  '北迴線',
#  '北迴線',
#  '北迴線',
#  '北迴線',
#  '北迴線',
#  '北迴線',
#  '北迴線',
#  '北迴線',
#  '北迴線',
#  '宜蘭線',
#  '宜蘭線、北迴線',
#  '宜蘭線',
#  '宜蘭線',
#  '宜蘭線',
#  '宜蘭線',
#  '宜蘭線',
#  '宜蘭線',
#  '宜蘭線',
#  '宜蘭線',
#  '宜蘭線',
#  '宜蘭線',
#  '宜蘭線',
#  '宜蘭線',
#  '宜蘭線',
#  '宜蘭線',
#  '宜蘭線',
#  '宜蘭線',
#  '宜蘭線',
#  '宜蘭線',
#  '宜蘭線',
#  '宜蘭線、平溪線',
#  '平溪線',
#  '平溪線',
#  '平溪線',
#  '平溪線',
#  '平溪線',
#  '平溪線',
#  '宜蘭線',
#  '宜蘭線、深澳線',
#  '深澳線',
#  '深澳線',
#  '宜蘭線',
#  '宜蘭線']

# %% [markdown]
# 現在就變得清潔溜溜~ 值得注意的是，這個資料並不符合tidy data的標準，但我只是要方便閱讀而已，因此對我來說不是tidy的沒關係

# %% [markdown]
# 再來是啟用時間的部分：

# %%
list(df_station.Open)
# Out:
# ['1891年10月20日',
#  '2003年5月9日',
#  '縱貫線：1899年7月20日',
#  '1891年10月20日',
#  '2007年5月8日',
#  '1902年6月1日',
#  '1891年10月20日',
#  '2007年12月30日',
#  '臺鐵：1899年7月20日（現今站房：2008年9月21日）臺北捷運：2008年12月25日台灣高鐵：2016年7月1日',
#  '臺鐵：1891年10月20日（現今站舍：2008年9月21日）松山新店線：2014年11月15日台北捷運環狀線：可行性研究中',
#  '縱貫線：1891年10月20日（現今站房：1989年9月2日）淡水信義線（淡水線）：1997年12月25日板南線（南港線）：1999年12月24日高鐵：2007年3月2日 機場線：2017年3月2日[3]',
#  '1901年8月25日（現今站房：1999年7月21日）',
#  '臺灣鐵路：1901年8月25日 明治34年(縱貫線)1965年3月5日(臺鐵中和線)1985年(板橋客車場)1999年7月21日(地下化新站)板南線：2006年5月31日台灣高鐵：2007年1月5日環狀線：2020年1月19日(試營運[1][2][3][4])；2020年1月31日(正式啟用[5][6][7])',
#  '縱貫線:2011年9月2日',
#  '1901年8月25日',
#  '2015年12月23日',
#  '1903年10月7日',
#  '1903年10月7日',
#  '縱貫線：1893年10月30日（現今臨時站房：2015年7月26日）',
#  '1902年6月1日',
#  '縱貫線：1893年10月30日 光緒19年',
#  '1900年4月10日',
#  '1893年（光緒19年）10月30日',
#  '1929年10月1日',
#  '2017年9月6日',
#  '2012年9月28日',
#  '1929年',
#  '1893年11月30日',
#  '1897年（明治30年）9月10日',
#  '2011年11月11日',
#  '2011年11月11日',
#  '2011年11月11日',
#  '1947年11月5日',
#  '2011年11月11日',
#  '1970年2月6日',
#  '2001年11月24日',
#  '1947年11月5日',
#  '1950年12月27日',
#  '1950年12月27日',
#  '1950年12月27日',
#  '1962年11月28日',
#  '1951年9月11日',
#  '1893年10月30日',
#  '2016年6月29日',
#  '1902年8月10日',
#  '1928年3月12日',
#  '1902年8月10日',
#  '1922年10月11日',
#  '1922年10月11日',
#  '1922年10月11日',
#  '1922年10月11日',
#  '1922年10月11日',
#  '1922年10月11日',
#  '1922年10月11日',
#  '1922年10月11日',
#  '1922年10月11日',
#  '1922年10月11日',
#  '1922年10月11日',
#  '1920年12月25日',
#  '1920年12月25日',
#  '1920年12月25日',
#  '1920年12月25日',
#  '1922年10月11日',
#  '1903年5月25日',
#  '1903年5月25日',
#  '1903年5月25日',
#  '1903年7月1日',
#  '1903年10月7日',
#  '1903年10月7日',
#  '1998年9月24日',
#  '1905年5月15日',
#  '1905年5月15日2016年10月16日：高架化車站',
#  '2018年10月28日',
#  '1905年5月15日',
#  '2018年10月28日',
#  '2018年10月28日',
#  '2002年11月22日2016年10月16日 (高架)',
#  '2018年10月28日',
#  '1905年5月15日：設站2016年10月16日：新站房第一階段復興路側站房第一月台(含A側與B側)及第二月台(A側)2018年10月28日：新站房第二階段臺灣大道側站房一樓轉運中心、站前廣場及西側二樓部分站房2020年8月18日：新站房第三階段第二月台(B側)與第三月台',
#  '2018年10月28日',
#  '1998年7月7日：設站2016年10月16日：高架化啟用',
#  '1905年5月15日',
#  '2006年12月1日',
#  '1905年5月15日(大肚停車場)1920年12月25日(王田停車場)',
#  '1905年3月26日[1]',
#  '1905年3月26日',
#  '2006年4月4日',
#  '1905年3月26日高架化：2014年11月2日',
#  '1958年10月24日',
#  '1905年3月26日',
#  '1905年3月26日',
#  '1905年1月15日',
#  '1922年1月14日',
#  '1922年1月14日',
#  '1922年1月14日',
#  '1922年1月14日',
#  '1922年1月14日',
#  '1922年1月14日',
#  '1907年6月20日',
#  '1905年10月15日',
#  '1904年2月1日',
#  '1903年12月15日',
#  '1958年10月24日',
#  '1903年12月15日',
#  '1903年12月15日',
#  '2005年9月8日',
#  '1902年4月20日',
#  '1902年4月20日',
#  '1911年3月20日',
#  '1903年4月20日',
#  '1901年12月16日',
#  '1960年6月1日',
#  '1901年12月16日',
#  '1902年4月20日',
#  '1901年12月16日',
#  '1901年5月15日',
#  '2010年7月14日',
#  '1901年5月15日',
#  '1903年3月10日2027年：預定新站啟用',
#  '2002年10月4日',
#  '1900年5月15日',
#  '1900年11月29日',
#  '2014年1月10日[1]',
#  '1901年12月11日',
#  '2011年1月2日',
#  '2011年1月2日',
#  '1900年11月29日',
#  '1902年12月15日',
#  '1900年（明治33年）12月15日（臺鐵）',
#  '台鐵：1901年5月15日高雄捷運：2008年3月9日',
#  '1900年11月29日',
#  '2006年12月1日',
#  '1900年11月29日',
#  '2018年10月14日',
#  ' 縱貫線：2018年10月14日 環狀輕軌：預計2021年底',
#  ' 縱貫線：2018年10月14日 環狀輕軌：預計2021年底',
#  '1908年2月1日',
#  '臺灣總督府交通局鐵道部- 1941年6月22日 (昭和16年)\n臺灣鐵路管理局 (後站)- 1971年10月31日 (民國60年)\n臺灣鐵路管理局 (臨時站)- 2002年3月28日 (民國91年)\n臺灣鐵路管理局 (永久站一期工程)- 2018年10月14日 (民國107年)\n臺灣鐵路管理局 (永久站二期工程)- 施工中，預計2023年完工 (民國112年)\n高雄捷運公司 (臨時站)- 2008年3月9日 (民國97年)\n\n高雄捷運公司 (永久站)- 2018年9月5日 (民國107年)',
#  ' 屏東線：2018年10月14日',
#  '屏東線：2018年10月14日 環狀輕軌：預計2023年12月',
#  ' 屏東線：2018年10月14日\xa0(2018-10-14) 黃線：規劃中',
#  '1907年10月1日[1]2018年10月14日（地下化啟用）',
#  '1908年6月25日',
#  '1907年10月1日[1]',
#  '1913年12月20日',
#  '1913年12月20日',
#  '1956年5月1日',
#  '1941年7月1日',
#  '1919年11月16日',
#  '1919年11月16日',
#  '1920年2月22日',
#  '1952年11月24日',
#  '1923年10月11日',
#  '台鐵：1940年7月19日捷運：規劃中',
#  '1940年7月19日',
#  '1940年7月19日',
#  '1953年1月16日',
#  '1941年12月15日',
#  '1992年10月5日',
#  '1992年10月5日',
#  '1992年10月5日',
#  '1992年10月5日',
#  '1992年10月5日',
#  '1992年10月5日',
#  '1992年10月5日',
#  '1988年1月1日',
#  '1985年7月15日',
#  '1985年7月15日',
#  '1982年6月27日',
#  '1982年6月27日',
#  '1922年4月20日',
#  '1922年4月20日',
#  '1923年7月14日',
#  '1922年4月20日',
#  '1924年8月27日',
#  '1924年9月1日',
#  '1926年1月20日',
#  '1924年5月1日',
#  '1924年5月1日',
#  '1917年11月1日',
#  '1917年11月1日',
#  '1915年1月26日',
#  '1914年3月8日',
#  '1918年11月1日',
#  '1913年11月20日',
#  '1914年3月8日',
#  '1912年1月25日',
#  '1915年9月16日',
#  '1918年11月1日啟用2018年7月10日（復站）',
#  '1913年5月1日',
#  '1910年12月16日',
#  '1934年4月20日',
#  '1911年9月25日',
#  '1914年1月29日',
#  '1979年2月8日（設站）2018年10月3日:新跨站式車站第一階段啟用2019年10月3日:新跨站式車站第二階段啟用',
#  '1975年7月26日',
#  '1975年7月26日',
#  '1975年7月26日',
#  '1979年2月8日',
#  '1979年2月8日',
#  '1979年2月8日',
#  '1980年2月1日',
#  '1980年2月1日',
#  '1980年2月1日',
#  '1980年2月1日',
#  '1980年2月1日',
#  '1919年3月24日',
#  '1968年4月15日',
#  '1920年11月22日',
#  '1919年3月24日',
#  '1919年3月24日',
#  '1936年7月20日',
#  '1919年3月24日',
#  '1919年3月24日',
#  '1921年2月25日',
#  '1919年11月15日',
#  '1937年5月1日',
#  '1920年4月25日',
#  '1920年12月10日',
#  '1920年12月10日',
#  '1920年12月10日',
#  '1920年12月10日',
#  '1953年5月1日',
#  '1924年12月1日',
#  '1924年12月1日',
#  '1923年10月11日',
#  '1922年9月13日',
#  '1922年5月16日',
#  '1956年10月12日',
#  '1929年10月1日',
#  '1972年7月30日',
#  '1929年10月1日',
#  '1929年10月1日',
#  '1929年10月1日',
#  '1920年1月27日',
#  '1919年5月5日',
#  '2014年1月9日',
#  '1967年8月25日-1989年8月21日2016年12月28日至今',
#  '1919年5月5日',
#  '1919年5月5日']

# %% [markdown]
# 比剛剛髒了非常多，好像沒有規律，但冷靜下來可以發現：我們要的啟用時間都是第一個日期。我不在意其他路線或站房的啟用日期，我只要這個車站本身第一次啟用的時間就好了。另外有些年代久遠的還有清領或日治時期的年號，這個也要一併去除。

# %%
df_station['Open'] = df_station.Open.str.replace('日(.+)', '日', regex=True).replace('(.+)\：', '', regex=True).replace('(.+):','', regex=True).replace('(.+)\-', '', regex=True).replace('\n(.+)','', regex=True).replace('\（(.+)\）', '', regex=True)

# %%
list(df_station.Open)
# Out:
# ['1891年10月20日',
#  '2003年5月9日',
#  '1899年7月20日',
#  '1891年10月20日',
#  '2007年5月8日',
#  '1902年6月1日',
#  '1891年10月20日',
#  '2007年12月30日',
#  '1899年7月20日',
#  '1891年10月20日',
#  '1891年10月20日',
#  '1901年8月25日',
#  '1901年8月25日',
#  '2011年9月2日',
#  '1901年8月25日',
#  '2015年12月23日',
#  '1903年10月7日',
#  '1903年10月7日',
#  '1893年10月30日',
#  '1902年6月1日',
#  '1893年10月30日',
#  '1900年4月10日',
#  '1893年10月30日',
#  '1929年10月1日',
#  '2017年9月6日',
#  '2012年9月28日',
#  '1929年',
#  '1893年11月30日',
#  '1897年9月10日',
#  '2011年11月11日',
#  '2011年11月11日',
#  '2011年11月11日',
#  '1947年11月5日',
#  '2011年11月11日',
#  '1970年2月6日',
#  '2001年11月24日',
#  '1947年11月5日',
#  '1950年12月27日',
#  '1950年12月27日',
#  '1950年12月27日',
#  '1962年11月28日',
#  '1951年9月11日',
#  '1893年10月30日',
#  '2016年6月29日',
#  '1902年8月10日',
#  '1928年3月12日',
#  '1902年8月10日',
#  '1922年10月11日',
#  '1922年10月11日',
#  '1922年10月11日',
#  '1922年10月11日',
#  '1922年10月11日',
#  '1922年10月11日',
#  '1922年10月11日',
#  '1922年10月11日',
#  '1922年10月11日',
#  '1922年10月11日',
#  '1922年10月11日',
#  '1920年12月25日',
#  '1920年12月25日',
#  '1920年12月25日',
#  '1920年12月25日',
#  '1922年10月11日',
#  '1903年5月25日',
#  '1903年5月25日',
#  '1903年5月25日',
#  '1903年7月1日',
#  '1903年10月7日',
#  '1903年10月7日',
#  '1998年9月24日',
#  '1905年5月15日',
#  '1905年5月15日',
#  '2018年10月28日',
#  '1905年5月15日',
#  '2018年10月28日',
#  '2018年10月28日',
#  '2002年11月22日',
#  '2018年10月28日',
#  '1905年5月15日',
#  '2018年10月28日',
#  '1998年7月7日',
#  '1905年5月15日',
#  '2006年12月1日',
#  '1905年5月15日',
#  '1905年3月26日',
#  '1905年3月26日',
#  '2006年4月4日',
#  '1905年3月26日',
#  '1958年10月24日',
#  '1905年3月26日',
#  '1905年3月26日',
#  '1905年1月15日',
#  '1922年1月14日',
#  '1922年1月14日',
#  '1922年1月14日',
#  '1922年1月14日',
#  '1922年1月14日',
#  '1922年1月14日',
#  '1907年6月20日',
#  '1905年10月15日',
#  '1904年2月1日',
#  '1903年12月15日',
#  '1958年10月24日',
#  '1903年12月15日',
#  '1903年12月15日',
#  '2005年9月8日',
#  '1902年4月20日',
#  '1902年4月20日',
#  '1911年3月20日',
#  '1903年4月20日',
#  '1901年12月16日',
#  '1960年6月1日',
#  '1901年12月16日',
#  '1902年4月20日',
#  '1901年12月16日',
#  '1901年5月15日',
#  '2010年7月14日',
#  '1901年5月15日',
#  '1903年3月10日',
#  '2002年10月4日',
#  '1900年5月15日',
#  '1900年11月29日',
#  '2014年1月10日',
#  '1901年12月11日',
#  '2011年1月2日',
#  '2011年1月2日',
#  '1900年11月29日',
#  '1902年12月15日',
#  '1900年12月15日',
#  '1901年5月15日',
#  '1900年11月29日',
#  '2006年12月1日',
#  '1900年11月29日',
#  '2018年10月14日',
#  '2018年10月14日',
#  '2018年10月14日',
#  '1908年2月1日',
#  ' 1941年6月22日\n',
#  '2018年10月14日',
#  '2018年10月14日',
#  '2018年10月14日',
#  '1907年10月1日',
#  '1908年6月25日',
#  '1907年10月1日',
#  '1913年12月20日',
#  '1913年12月20日',
#  '1956年5月1日',
#  '1941年7月1日',
#  '1919年11月16日',
#  '1919年11月16日',
#  '1920年2月22日',
#  '1952年11月24日',
#  '1923年10月11日',
#  '1940年7月19日',
#  '1940年7月19日',
#  '1940年7月19日',
#  '1953年1月16日',
#  '1941年12月15日',
#  '1992年10月5日',
#  '1992年10月5日',
#  '1992年10月5日',
#  '1992年10月5日',
#  '1992年10月5日',
#  '1992年10月5日',
#  '1992年10月5日',
#  '1988年1月1日',
#  '1985年7月15日',
#  '1985年7月15日',
#  '1982年6月27日',
#  '1982年6月27日',
#  '1922年4月20日',
#  '1922年4月20日',
#  '1923年7月14日',
#  '1922年4月20日',
#  '1924年8月27日',
#  '1924年9月1日',
#  '1926年1月20日',
#  '1924年5月1日',
#  '1924年5月1日',
#  '1917年11月1日',
#  '1917年11月1日',
#  '1915年1月26日',
#  '1914年3月8日',
#  '1918年11月1日',
#  '1913年11月20日',
#  '1914年3月8日',
#  '1912年1月25日',
#  '1915年9月16日',
#  '1918年11月1日',
#  '1913年5月1日',
#  '1910年12月16日',
#  '1934年4月20日',
#  '1911年9月25日',
#  '1914年1月29日',
#  '1979年2月8日',
#  '1975年7月26日',
#  '1975年7月26日',
#  '1975年7月26日',
#  '1979年2月8日',
#  '1979年2月8日',
#  '1979年2月8日',
#  '1980年2月1日',
#  '1980年2月1日',
#  '1980年2月1日',
#  '1980年2月1日',
#  '1980年2月1日',
#  '1919年3月24日',
#  '1968年4月15日',
#  '1920年11月22日',
#  '1919年3月24日',
#  '1919年3月24日',
#  '1936年7月20日',
#  '1919年3月24日',
#  '1919年3月24日',
#  '1921年2月25日',
#  '1919年11月15日',
#  '1937年5月1日',
#  '1920年4月25日',
#  '1920年12月10日',
#  '1920年12月10日',
#  '1920年12月10日',
#  '1920年12月10日',
#  '1953年5月1日',
#  '1924年12月1日',
#  '1924年12月1日',
#  '1923年10月11日',
#  '1922年9月13日',
#  '1922年5月16日',
#  '1956年10月12日',
#  '1929年10月1日',
#  '1972年7月30日',
#  '1929年10月1日',
#  '1929年10月1日',
#  '1929年10月1日',
#  '1920年1月27日',
#  '1919年5月5日',
#  '2014年1月9日',
#  '1967年8月25日',
#  '1919年5月5日',
#  '1919年5月5日']

# %% [markdown]
# 看起來舒服多了，接下來就是去除空格，把年月日換成斜線，比較好在表格中轉換為日期時間格式

# %%
df_station['Open'] = df_station.Open.str.strip()

# %%
df_station['Open'] = df_station.Open.str.replace('年','/').replace('月','/', regex=True).replace('日','', regex=True)

# %% [markdown]
# 另外有一個車站只有年份沒有日期，因此我上網找資料將他補上：

# %%
df_station.loc[df_station.Open == '1929/', 'Open'] = '1929/11/1'

# %%
list(df_station.Open)
# Out:
# ['1891/10/20',
#  '2003/5/9',
#  '1899/7/20',
#  '1891/10/20',
#  '2007/5/8',
#  '1902/6/1',
#  '1891/10/20',
#  '2007/12/30',
#  '1899/7/20',
#  '1891/10/20',
#  '1891/10/20',
#  '1901/8/25',
#  '1901/8/25',
#  '2011/9/2',
#  '1901/8/25',
#  '2015/12/23',
#  '1903/10/7',
#  '1903/10/7',
#  '1893/10/30',
#  '1902/6/1',
#  '1893/10/30',
#  '1900/4/10',
#  '1893/10/30',
#  '1929/10/1',
#  '2017/9/6',
#  '2012/9/28',
#  '1929/11/1',
#  '1893/11/30',
#  '1897/9/10',
#  '2011/11/11',
#  '2011/11/11',
#  '2011/11/11',
#  '1947/11/5',
#  '2011/11/11',
#  '1970/2/6',
#  '2001/11/24',
#  '1947/11/5',
#  '1950/12/27',
#  '1950/12/27',
#  '1950/12/27',
#  '1962/11/28',
#  '1951/9/11',
#  '1893/10/30',
#  '2016/6/29',
#  '1902/8/10',
#  '1928/3/12',
#  '1902/8/10',
#  '1922/10/11',
#  '1922/10/11',
#  '1922/10/11',
#  '1922/10/11',
#  '1922/10/11',
#  '1922/10/11',
#  '1922/10/11',
#  '1922/10/11',
#  '1922/10/11',
#  '1922/10/11',
#  '1922/10/11',
#  '1920/12/25',
#  '1920/12/25',
#  '1920/12/25',
#  '1920/12/25',
#  '1922/10/11',
#  '1903/5/25',
#  '1903/5/25',
#  '1903/5/25',
#  '1903/7/1',
#  '1903/10/7',
#  '1903/10/7',
#  '1998/9/24',
#  '1905/5/15',
#  '1905/5/15',
#  '2018/10/28',
#  '1905/5/15',
#  '2018/10/28',
#  '2018/10/28',
#  '2002/11/22',
#  '2018/10/28',
#  '1905/5/15',
#  '2018/10/28',
#  '1998/7/7',
#  '1905/5/15',
#  '2006/12/1',
#  '1905/5/15',
#  '1905/3/26',
#  '1905/3/26',
#  '2006/4/4',
#  '1905/3/26',
#  '1958/10/24',
#  '1905/3/26',
#  '1905/3/26',
#  '1905/1/15',
#  '1922/1/14',
#  '1922/1/14',
#  '1922/1/14',
#  '1922/1/14',
#  '1922/1/14',
#  '1922/1/14',
#  '1907/6/20',
#  '1905/10/15',
#  '1904/2/1',
#  '1903/12/15',
#  '1958/10/24',
#  '1903/12/15',
#  '1903/12/15',
#  '2005/9/8',
#  '1902/4/20',
#  '1902/4/20',
#  '1911/3/20',
#  '1903/4/20',
#  '1901/12/16',
#  '1960/6/1',
#  '1901/12/16',
#  '1902/4/20',
#  '1901/12/16',
#  '1901/5/15',
#  '2010/7/14',
#  '1901/5/15',
#  '1903/3/10',
#  '2002/10/4',
#  '1900/5/15',
#  '1900/11/29',
#  '2014/1/10',
#  '1901/12/11',
#  '2011/1/2',
#  '2011/1/2',
#  '1900/11/29',
#  '1902/12/15',
#  '1900/12/15',
#  '1901/5/15',
#  '1900/11/29',
#  '2006/12/1',
#  '1900/11/29',
#  '2018/10/14',
#  '2018/10/14',
#  '2018/10/14',
#  '1908/2/1',
#  '1941/6/22',
#  '2018/10/14',
#  '2018/10/14',
#  '2018/10/14',
#  '1907/10/1',
#  '1908/6/25',
#  '1907/10/1',
#  '1913/12/20',
#  '1913/12/20',
#  '1956/5/1',
#  '1941/7/1',
#  '1919/11/16',
#  '1919/11/16',
#  '1920/2/22',
#  '1952/11/24',
#  '1923/10/11',
#  '1940/7/19',
#  '1940/7/19',
#  '1940/7/19',
#  '1953/1/16',
#  '1941/12/15',
#  '1992/10/5',
#  '1992/10/5',
#  '1992/10/5',
#  '1992/10/5',
#  '1992/10/5',
#  '1992/10/5',
#  '1992/10/5',
#  '1988/1/1',
#  '1985/7/15',
#  '1985/7/15',
#  '1982/6/27',
#  '1982/6/27',
#  '1922/4/20',
#  '1922/4/20',
#  '1923/7/14',
#  '1922/4/20',
#  '1924/8/27',
#  '1924/9/1',
#  '1926/1/20',
#  '1924/5/1',
#  '1924/5/1',
#  '1917/11/1',
#  '1917/11/1',
#  '1915/1/26',
#  '1914/3/8',
#  '1918/11/1',
#  '1913/11/20',
#  '1914/3/8',
#  '1912/1/25',
#  '1915/9/16',
#  '1918/11/1',
#  '1913/5/1',
#  '1910/12/16',
#  '1934/4/20',
#  '1911/9/25',
#  '1914/1/29',
#  '1979/2/8',
#  '1975/7/26',
#  '1975/7/26',
#  '1975/7/26',
#  '1979/2/8',
#  '1979/2/8',
#  '1979/2/8',
#  '1980/2/1',
#  '1980/2/1',
#  '1980/2/1',
#  '1980/2/1',
#  '1980/2/1',
#  '1919/3/24',
#  '1968/4/15',
#  '1920/11/22',
#  '1919/3/24',
#  '1919/3/24',
#  '1936/7/20',
#  '1919/3/24',
#  '1919/3/24',
#  '1921/2/25',
#  '1919/11/15',
#  '1937/5/1',
#  '1920/4/25',
#  '1920/12/10',
#  '1920/12/10',
#  '1920/12/10',
#  '1920/12/10',
#  '1953/5/1',
#  '1924/12/1',
#  '1924/12/1',
#  '1923/10/11',
#  '1922/9/13',
#  '1922/5/16',
#  '1956/10/12',
#  '1929/10/1',
#  '1972/7/30',
#  '1929/10/1',
#  '1929/10/1',
#  '1929/10/1',
#  '1920/1/27',
#  '1919/5/5',
#  '2014/1/9',
#  '1967/8/25',
#  '1919/5/5',
#  '1919/5/5']

# %% [markdown]
# 超級乾淨的！接下來就是轉換成內建的日期時間格式，這能讓我比較好對時間做運算(如果有需求的話)

# %%
df_station['Open'] = pd.to_datetime(df_station.Open)

# %%
df_station.dtypes
# Out:
# stationCode              object
# stationName              object
# stationEName             object
# stationAddrTw            object
# stationAddrEn            object
# stationTel               object
# gps                      object
# Level                    object
# Link                     object
# Open             datetime64[ns]
# Line                     object
# dtype: object

# %% [markdown]
# 至此處理完成，當然我有確認其他欄位沒有任何問題才敢下此結論。存成.csv跟.json檔以防不時之需

# %%
df_station.to_csv('df_station.csv')

# %%
import json

# %%
df_station = pd.read_csv('df_station.csv', index_col=0)

# %%
df_station.to_json('df_station.json', orient='records')

# %%
with open(r"df_station.json", "r") as read_file:
    data2 = json.load(read_file)

# %%
data2
# Out:
# [{'stationCode': 900,
#   'stationName': '基隆',
#   'stationEName': 'Keelung',
#   'stationAddrTw': '基隆市中山區民治里1鄰中山一路16之 1號',
#   'stationAddrEn': 'No. 16-1, Zhongshan 1st Rd, Zhongshan Dist., Keelung City',
#   'stationTel': '02-24263743',
#   'gps': '25.13401 121.74013',
#   'Level': '一等',
#   'Link': '/wiki/%E5%9F%BA%E9%9A%86%E8%BB%8A%E7%AB%99',
#   'Open': '1891-10-20',
#   'Line': '縱貫線、基隆捷運（規劃中）'},
#  {'stationCode': 910,
#   'stationName': '三坑',
#   'stationEName': 'Sankeng',
#   'stationAddrTw': '基隆市仁愛區德厚里龍安街 206 號',
#   'stationAddrEn': 'No. 206, Long’an St., Ren`ai Dist., Keelung City',
#   'stationTel': '02-24230289',
#   'gps': '25.12305 121.74202',
#   'Level': '簡易',
#   'Link': '/wiki/%E4%B8%89%E5%9D%91%E8%BB%8A%E7%AB%99',
#   'Open': '2003-05-09',
#   'Line': '縱貫線'},
#  {'stationCode': 920,
#   'stationName': '八堵',
#   'stationEName': 'Badu',
#   'stationAddrTw': '基隆市暖暖區八南里八堵路 142 號',
#   'stationAddrEn': 'No. 142, Badu Rd., Nuannuan Dist., Keelung City',
#   'stationTel': '02-24560841',
#   'gps': '25.10843 121.72898',
#   'Level': '二等',
#   'Link': '/wiki/%E5%85%AB%E5%A0%B5%E8%BB%8A%E7%AB%99',
#   'Open': '1899-07-20',
#   'Line': '縱貫線、宜蘭線'},
#  {'stationCode': 930,
#   'stationName': '七堵',
#   'stationEName': 'Qidu',
#   'stationAddrTw': '基隆市七堵區長興里東新街 2 號',
#   'stationAddrEn': 'No. 2, Dongxin St., Qidu Dist., Keelung City',
#   'stationTel': '02-24553426',
#   'gps': '25.09294 121.71415',
#   'Level': '一等',
#   'Link': '/wiki/%E4%B8%83%E5%A0%B5%E8%BB%8A%E7%AB%99',
#   'Open': '1891-10-20',
#   'Line': '縱貫線'},
#  {'stationCode': 940,
#   'stationName': '百福',
#   'stationEName': 'Baifu',
#   'stationAddrTw': '基隆市七堵區堵南里明德三路 1 之 1 號',
#   'stationAddrEn': 'No. 1-1, Mingde 3rd Rd., Qidu Dist., Keelung City',
#   'stationTel': '02-24528372',
#   'gps': '25.07803 121.69373',
#   'Level': '簡易',
#   'Link': '/wiki/%E7%99%BE%E7%A6%8F%E8%BB%8A%E7%AB%99',
#   'Open': '2007-05-08',
#   'Line': '縱貫線'},
#  {'stationCode': 950,
#   'stationName': '五堵',
#   'stationEName': 'Wudu',
#   'stationAddrTw': '新北市汐止區長安里長安路 17 號',
#   'stationAddrEn': 'No. 17, Chang’an Rd., Xizhi Dist., New Taipei City',
#   'stationTel': '02-86476200',
#   'gps': '25.07784 121.66764',
#   'Level': '簡易',
#   'Link': '/wiki/%E4%BA%94%E5%A0%B5%E8%BB%8A%E7%AB%99',
#   'Open': '1902-06-01',
#   'Line': '縱貫線'},
#  {'stationCode': 960,
#   'stationName': '汐止',
#   'stationEName': 'Xizhi',
#   'stationAddrTw': '新北市汐止區信望里信義路 1 號',
#   'stationAddrEn': 'No. 1, Xinyi Rd., Xizhi Dist., New Taipei City',
#   'stationTel': '02-26415096',
#   'gps': '25.06894 121.66244',
#   'Level': '二等',
#   'Link': '/wiki/%E6%B1%90%E6%AD%A2%E8%BB%8A%E7%AB%99',
#   'Open': '1891-10-20',
#   'Line': '縱貫線'},
#  {'stationCode': 970,
#   'stationName': '汐科',
#   'stationEName': 'Xike',
#   'stationAddrTw': '新北市汐止區大同里大同路二段 182 號',
#   'stationAddrEn': 'No. 182, Sec. 2, Datong Rd., Xizhi Dist., New Taipei City',
#   'stationTel': '02-23815226#8730',
#   'gps': '25.06241 121.64669',
#   'Level': '簡易',
#   'Link': '/wiki/%E6%B1%90%E7%A7%91%E8%BB%8A%E7%AB%99',
#   'Open': '2007-12-30',
#   'Line': '縱貫線、民生汐止線(規劃中)基隆捷運線(規劃中)'},
#  {'stationCode': 980,
#   'stationName': '南港',
#   'stationEName': 'Nangang',
#   'stationAddrTw': '臺北市南港區南港里南港路一段 313 號',
#   'stationAddrEn': 'No. 313, Sec. 1, Nangang Rd., Nangang Dist., Taipei City',
#   'stationTel': '02-27838645',
#   'gps': '25.05348 121.60706',
#   'Level': '一等',
#   'Link': '/wiki/%E5%8D%97%E6%B8%AF%E8%BB%8A%E7%AB%99',
#   'Open': '1899-07-20',
#   'Line': '臺灣鐵路縱貫線、北宜直線鐵路（規劃中）、基隆捷運（規劃中）、臺灣高鐵、板南線'},
#  {'stationCode': 990,
#   'stationName': '松山',
#   'stationEName': 'Songshan',
#   'stationAddrTw': '臺北市信義區永吉里松山路 11 號B1',
#   'stationAddrEn': 'No. 11, Songshan Rd., Xinyi Dist., Taipei City',
#   'stationTel': '02-27673819',
#   'gps': '25.04936 121.57807',
#   'Level': '一等',
#   'Link': '/wiki/%E6%9D%BE%E5%B1%B1%E8%BB%8A%E7%AB%99_(%E5%8F%B0%E7%81%A3)',
#   'Open': '1891-10-20',
#   'Line': '臺灣鐵路縱貫線、松山新店線、環狀線（規劃中）'},
#  {'stationCode': 1000,
#   'stationName': '臺北',
#   'stationEName': 'Taipei',
#   'stationAddrTw': '臺北市中正區黎明里北平西路 3 號',
#   'stationAddrEn': 'No. 3, Beiping W. Rd., Zhongzheng Dist., Taipei City',
#   'stationTel': '02-23713558',
#   'gps': '25.04771 121.51784',
#   'Level': '特等',
#   'Link': '/wiki/%E8%87%BA%E5%8C%97%E8%BB%8A%E7%AB%99',
#   'Open': '1891-10-20',
#   'Line': '臺鐵縱貫線、臺灣高鐵、淡水信義線、板南線、機場線'},
#  {'stationCode': 1010,
#   'stationName': '萬華',
#   'stationEName': 'Wanhua',
#   'stationAddrTw': '臺北市萬華區富福里康定路 382 號',
#   'stationAddrEn': 'No. 382, Kangding Rd., Wanhua Dist., Taipei City',
#   'stationTel': '02-23020481',
#   'gps': '25.03348 121.49984',
#   'Level': '一等',
#   'Link': '/wiki/%E8%90%AC%E8%8F%AF%E8%BB%8A%E7%AB%99',
#   'Open': '1901-08-25',
#   'Line': '縱貫線'},
#  {'stationCode': 1020,
#   'stationName': '板橋',
#   'stationEName': 'Banqiao',
#   'stationAddrTw': '新北市板橋區新民里站前路',
#   'stationAddrEn': 'No. 7, Sec. 2, Xianmin Blvd., Banqiao Dist., New Taipei City',
#   'stationTel': '02-89691036',
#   'gps': '25.01469 121.46352',
#   'Level': '一等',
#   'Link': '/wiki/%E6%9D%BF%E6%A9%8B%E8%BB%8A%E7%AB%99_(%E8%87%BA%E7%81%A3)',
#   'Open': '1901-08-25',
#   'Line': '臺灣鐵路縱貫線、臺灣高鐵、板南線（板橋線）、環狀線'},
#  {'stationCode': 1030,
#   'stationName': '浮洲',
#   'stationEName': 'Fuzhou',
#   'stationAddrTw': '新北市板橋區僑中里僑中二街 156 號',
#   'stationAddrEn': 'No. 156, Qiaozhong 2nd St., Banqiao Dist., New Taipei City',
#   'stationTel': '02-23815226#4665',
#   'gps': '25.00419 121.44477',
#   'Level': '簡易',
#   'Link': '/wiki/%E6%B5%AE%E6%B4%B2%E8%BB%8A%E7%AB%99',
#   'Open': '2011-09-02',
#   'Line': '縱貫線、泰山板橋輕軌'},
#  {'stationCode': 1040,
#   'stationName': '樹林',
#   'stationEName': 'Shulin',
#   'stationAddrTw': '新北市樹林區樹北里鎮前街 112 號',
#   'stationAddrEn': 'No. 112, Zhenqian St., Shulin Dist., New Taipei City',
#   'stationTel': '02-26812052',
#   'gps': '24.99121 121.42481',
#   'Level': '一等',
#   'Link': '/wiki/%E6%A8%B9%E6%9E%97%E8%BB%8A%E7%AB%99',
#   'Open': '1901-08-25',
#   'Line': '縱貫線'},
#  {'stationCode': 1050,
#   'stationName': '南樹林',
#   'stationEName': 'South Shulin',
#   'stationAddrTw': '新北市樹林區東山里中山路二段 230 號',
#   'stationAddrEn': 'No. 230, Sec. 2, Zhongshan Rd., Shulin Dist., New Taipei City',
#   'stationTel': '02-26812052',
#   'gps': '24.98034 121.40891',
#   'Level': '簡易',
#   'Link': '/wiki/%E5%8D%97%E6%A8%B9%E6%9E%97%E8%BB%8A%E7%AB%99',
#   'Open': '2015-12-23',
#   'Line': '縱貫線'},
#  {'stationCode': 1060,
#   'stationName': '山佳',
#   'stationEName': 'Shanjia',
#   'stationAddrTw': '新北市樹林區中山里山佳街 28 號',
#   'stationAddrEn': 'No. 28, Shanjia St., Shulin Dist., New Taipei City',
#   'stationTel': '02-26808874',
#   'gps': '24.97233 121.39273',
#   'Level': '三等',
#   'Link': '/wiki/%E5%B1%B1%E4%BD%B3%E8%BB%8A%E7%AB%99',
#   'Open': '1903-10-07',
#   'Line': '縱貫線'},
#  {'stationCode': 1070,
#   'stationName': '鶯歌',
#   'stationEName': 'Yingge',
#   'stationAddrTw': '新北市鶯歌區東鶯里文化路 68 號',
#   'stationAddrEn': 'No. 68, Wenhua Rd., Yingge Dist., New Taipei City',
#   'stationTel': '02-26792004',
#   'gps': '24.95432 121.35535',
#   'Level': '二等',
#   'Link': '/wiki/%E9%B6%AF%E6%AD%8C%E8%BB%8A%E7%AB%99',
#   'Open': '1903-10-07',
#   'Line': '縱貫線、三鶯線（興建中）三鶯纜車（全案暫緩）'},
#  {'stationCode': 1080,
#   'stationName': '桃園',
#   'stationEName': 'Taoyuan',
#   'stationAddrTw': '桃園市桃園區武陵里中正路 1 號',
#   'stationAddrEn': 'No. 1, Zhongzheng Rd., Taoyuan Dist., Taoyuan City',
#   'stationTel': '03-3767050',
#   'gps': '24.98941 121.31399',
#   'Level': '一等',
#   'Link': '/wiki/%E6%A1%83%E5%9C%92%E8%BB%8A%E7%AB%99_(%E8%87%BA%E9%90%B5)',
#   'Open': '1893-10-30',
#   'Line': '縱貫線、綠線（興建中）、棕線（規劃中）'},
#  {'stationCode': 1090,
#   'stationName': '內壢',
#   'stationEName': 'Neili',
#   'stationAddrTw': '桃園市中壢區中原里中華路一段 267 號',
#   'stationAddrEn': 'No. 267, Sec. 1, Zhonghua Rd., Zhongli Dist., Taoyuan City',
#   'stationTel': '03-4559725',
#   'gps': '24.97287 121.25814',
#   'Level': '三等',
#   'Link': '/wiki/%E5%85%A7%E5%A3%A2%E8%BB%8A%E7%AB%99',
#   'Open': '1902-06-01',
#   'Line': '縱貫線'},
#  {'stationCode': 1100,
#   'stationName': '中壢',
#   'stationEName': 'Zhongli_Taoyuan',
#   'stationAddrTw': '桃園市中壢區石頭里中和路 139 號',
#   'stationAddrEn': 'No. 139, Zhonghe Rd., Zhongli Dist., Taoyuan City',
#   'stationTel': '03-4223235',
#   'gps': '24.95382 121.22571',
#   'Level': '一等',
#   'Link': '/wiki/%E4%B8%AD%E5%A3%A2%E8%BB%8A%E7%AB%99',
#   'Open': '1893-10-30',
#   'Line': '縱貫線、機場線（興建中）'},
#  {'stationCode': 1110,
#   'stationName': '埔心',
#   'stationEName': 'Puxin',
#   'stationAddrTw': '桃園市楊梅區埔心里永美路 208 號',
#   'stationAddrEn': 'No. 208, Yongmei Rd., Yangmei Dist., Taoyuan City',
#   'stationTel': '03-4827100',
#   'gps': '24.91945 121.18366',
#   'Level': '三等',
#   'Link': '/wiki/%E5%9F%94%E5%BF%83%E8%BB%8A%E7%AB%99',
#   'Open': '1900-04-10',
#   'Line': '縱貫線'},
#  {'stationCode': 1120,
#   'stationName': '楊梅',
#   'stationEName': 'Yangmei',
#   'stationAddrTw': '桃園市楊梅區楊梅里大成路 256 號',
#   'stationAddrEn': 'No. 256, Dacheng Rd., Yangmei Dist., Taoyuan City',
#   'stationTel': '03-4782893',
#   'gps': '24.91391 121.14634',
#   'Level': '三等',
#   'Link': '/wiki/%E6%A5%8A%E6%A2%85%E8%BB%8A%E7%AB%99',
#   'Open': '1893-10-30',
#   'Line': '縱貫線'},
#  {'stationCode': 1130,
#   'stationName': '富岡',
#   'stationEName': 'Fugang',
#   'stationAddrTw': '桃園市楊梅區富岡里成功路 37 號',
#   'stationAddrEn': 'No. 37, Chenggong Rd., Yangmei Dist., Taoyuan City',
#   'stationTel': '03-4723754',
#   'gps': '24.93462 121.08313',
#   'Level': '三等',
#   'Link': '/wiki/%E5%AF%8C%E5%B2%A1%E8%BB%8A%E7%AB%99_(%E8%87%BA%E9%90%B5)',
#   'Open': '1929-10-01',
#   'Line': '縱貫線'},
#  {'stationCode': 1140,
#   'stationName': '新富',
#   'stationEName': 'Xinfu',
#   'stationAddrTw': '桃園市楊梅區富豐里富全街 1 號',
#   'stationAddrEn': 'No. 1, Fuquan St., Yangmei Dist., Taoyuan City',
#   'stationTel': '03-4723754',
#   'gps': '24.93107 121.06759',
#   'Level': '招呼',
#   'Link': '/wiki/%E6%96%B0%E5%AF%8C%E8%BB%8A%E7%AB%99',
#   'Open': '2017-09-06',
#   'Line': '縱貫線'},
#  {'stationCode': 1150,
#   'stationName': '北湖',
#   'stationEName': 'Beihu',
#   'stationAddrTw': '新竹縣湖口鄉東興村北湖路 1 號',
#   'stationAddrEn': 'No. 1, Beihu Rd., Hukou Township, Hsinchu County',
#   'stationTel': '03-5993850',
#   'gps': '24.92191 121.05586',
#   'Level': '甲簡',
#   'Link': '/wiki/%E5%8C%97%E6%B9%96%E8%BB%8A%E7%AB%99',
#   'Open': '2012-09-28',
#   'Line': '縱貫線'},
#  {'stationCode': 1160,
#   'stationName': '湖口',
#   'stationEName': 'Hukou',
#   'stationAddrTw': '新竹縣湖口鄉仁勢村中山路二段 121 號',
#   'stationAddrEn': 'No. 121, Sec. 2, Zhongshan Rd., Hukou Township, Hsinchu County',
#   'stationTel': '03-5992192',
#   'gps': '24.90292 121.04412',
#   'Level': '三等',
#   'Link': '/wiki/%E6%B9%96%E5%8F%A3%E8%BB%8A%E7%AB%99',
#   'Open': '1929-11-01',
#   'Line': '縱貫線'},
#  {'stationCode': 1170,
#   'stationName': '新豐',
#   'stationEName': 'Xinfeng',
#   'stationAddrTw': '新竹縣新豐鄉山崎村新興路 202 號',
#   'stationAddrEn': 'No. 202, Xinxing Rd., Xinfeng Township, Hsinchu County',
#   'stationTel': '03-5596314',
#   'gps': '24.86961 120.99654',
#   'Level': '三等',
#   'Link': '/wiki/%E6%96%B0%E8%B1%90%E8%BB%8A%E7%AB%99',
#   'Open': '1893-11-30',
#   'Line': '縱貫線'},
#  {'stationCode': 1180,
#   'stationName': '竹北',
#   'stationEName': 'Zhubei',
#   'stationAddrTw': '新竹縣竹義里和平街 59 號',
#   'stationAddrEn': 'No. 59, Heping St., , Hsinchu County',
#   'stationTel': '03-5552024',
#   'gps': '24.83892 121.00936',
#   'Level': '三等',
#   'Link': '/wiki/%E7%AB%B9%E5%8C%97%E8%BB%8A%E7%AB%99',
#   'Open': '1897-09-10',
#   'Line': '縱貫線'},
#  {'stationCode': 1190,
#   'stationName': '北新竹',
#   'stationEName': 'North Hsinchu',
#   'stationAddrTw': '新竹市 東區東園里中華路一段 291 之 2 號',
#   'stationAddrEn': 'No. 291-2, Sec. 1, Zhonghua Rd.,  , Hsinchu\xa0City',
#   'stationTel': '03-5237441',
#   'gps': '24.80876 120.98385',
#   'Level': '簡易',
#   'Link': '/wiki/%E5%8C%97%E6%96%B0%E7%AB%B9%E8%BB%8A%E7%AB%99',
#   'Open': '2011-11-11',
#   'Line': '縱貫線、內灣線'},
#  {'stationCode': 1191,
#   'stationName': '千甲',
#   'stationEName': 'Qianjia',
#   'stationAddrTw': '新竹市 東區水源里千甲路 142 號',
#   'stationAddrEn': 'No. 142, Qianjia Rd.,  , Hsinchu\xa0City',
#   'stationTel': '03-5237441',
#   'gps': '24.80669 121.00301',
#   'Level': '簡易',
#   'Link': '/wiki/%E5%8D%83%E7%94%B2%E8%BB%8A%E7%AB%99',
#   'Open': '2011-11-11',
#   'Line': '內灣線'},
#  {'stationCode': 1192,
#   'stationName': '新莊',
#   'stationEName': 'Xinzhuang',
#   'stationAddrTw': '新竹市 東區新莊里關東路 310 號',
#   'stationAddrEn': 'No. 310, Guandong Rd.,  , Hsinchu\xa0City',
#   'stationTel': '03-5237441',
#   'gps': '24.78819 121.02182',
#   'Level': '簡易',
#   'Link': '/wiki/%E6%96%B0%E8%8E%8A%E8%BB%8A%E7%AB%99_(%E6%96%B0%E7%AB%B9%E5%B8%82)',
#   'Open': '2011-11-11',
#   'Line': '內灣線'},
#  {'stationCode': 1193,
#   'stationName': '竹中',
#   'stationEName': 'Zhuzhong',
#   'stationAddrTw': '新竹縣竹東鎮頭重里竹中路 145 號',
#   'stationAddrEn': 'No. 145, Zhuzhong Rd., Zhudong Township, Hsinchu County',
#   'stationTel': '03-5962042',
#   'gps': '24.78125 121.03117',
#   'Level': '甲簡',
#   'Link': '/wiki/%E7%AB%B9%E4%B8%AD%E8%BB%8A%E7%AB%99',
#   'Open': '1947-11-05',
#   'Line': '內灣線、六家線'},
#  {'stationCode': 1194,
#   'stationName': '六家',
#   'stationEName': 'Liujia',
#   'stationAddrTw': '新竹縣竹北市隘口里復興三路二段 229 號',
#   'stationAddrEn': 'No. 229, Sec. 2, Fuxing 3rd Rd., Zhubei City, Hsinchu County',
#   'stationTel': '03-5962042',
#   'gps': '24.80751 121.03921',
#   'Level': '乙簡',
#   'Link': '/wiki/%E5%85%AD%E5%AE%B6%E8%BB%8A%E7%AB%99',
#   'Open': '2011-11-11',
#   'Line': '六家線'},
#  {'stationCode': 1201,
#   'stationName': '上員',
#   'stationEName': 'Shangyuan',
#   'stationAddrTw': '新竹縣竹東鎮上員里光明路 (無站房)',
#   'stationAddrEn': 'Guangming Rd. (No Station Building), Zhudong Township, Hsinchu County',
#   'stationTel': '03-5962042',
#   'gps': '24.77797 121.05554',
#   'Level': '招呼',
#   'Link': '/wiki/%E4%B8%8A%E5%93%A1%E8%BB%8A%E7%AB%99',
#   'Open': '1970-02-06',
#   'Line': '內灣線'},
#  {'stationCode': 1202,
#   'stationName': '榮華',
#   'stationEName': 'Ronghua',
#   'stationAddrTw': '新竹縣竹東鎮仁愛里北興路 (無站房)',
#   'stationAddrEn': 'Beixing Rd. (No Station Building), Zhudong Township, Hsinchu County',
#   'stationTel': '03-5962042',
#   'gps': '24.74851 121.08296',
#   'Level': '招呼',
#   'Link': '/wiki/%E6%A6%AE%E8%8F%AF%E8%BB%8A%E7%AB%99',
#   'Open': '2001-11-24',
#   'Line': '內灣線'},
#  {'stationCode': 1203,
#   'stationName': '竹東',
#   'stationEName': 'Zhudong',
#   'stationAddrTw': '新竹縣竹東鎮雞林里東林路 196 號',
#   'stationAddrEn': 'No. 196, Donglin Rd., Zhudong Township, Hsinchu County',
#   'stationTel': '03-5962042',
#   'gps': '24.73811 121.09465',
#   'Level': '二等',
#   'Link': '/wiki/%E7%AB%B9%E6%9D%B1%E8%BB%8A%E7%AB%99',
#   'Open': '1947-11-05',
#   'Line': '內灣線'},
#  {'stationCode': 1204,
#   'stationName': '橫山',
#   'stationEName': 'Hengshan',
#   'stationAddrTw': '新竹縣橫山鄉橫山村橫山路 97 號 (無站房)',
#   'stationAddrEn': 'No. 97, Hengshan Rd. (No Station Building), Hengshan Township, Hsinchu County',
#   'stationTel': '03-5962042',
#   'gps': '24.72051 121.11657',
#   'Level': '招呼',
#   'Link': '/wiki/%E6%A9%AB%E5%B1%B1%E8%BB%8A%E7%AB%99_(%E6%96%B0%E7%AB%B9%E7%B8%A3)',
#   'Open': '1950-12-27',
#   'Line': '內灣線'},
#  {'stationCode': 1205,
#   'stationName': '九讚頭',
#   'stationEName': 'Jiuzantou',
#   'stationAddrTw': '新竹縣橫山鄉大肚村中豐路二段 286 巷 29 號',
#   'stationAddrEn': 'No. 29, Ln. 286, Sec. 2, Zhongfeng Rd., Hengshan Township, Hsinchu County',
#   'stationTel': '03-5962042',
#   'gps': '24.72068 121.13621',
#   'Level': '乙簡',
#   'Link': '/wiki/%E4%B9%9D%E8%AE%9A%E9%A0%AD%E8%BB%8A%E7%AB%99',
#   'Open': '1950-12-27',
#   'Line': '內灣線'},
#  {'stationCode': 1206,
#   'stationName': '合興',
#   'stationEName': 'Hexing',
#   'stationAddrTw': '新竹縣橫山鄉力行村中山街一段 17 號',
#   'stationAddrEn': 'No. 17, Sec. 1, Zhongshan St., Hengshan Township, Hsinchu County',
#   'stationTel': '03-5962042',
#   'gps': '24.71649 121.15434',
#   'Level': '招呼',
#   'Link': '/wiki/%E5%90%88%E8%88%88%E8%BB%8A%E7%AB%99',
#   'Open': '1950-12-27',
#   'Line': '內灣線'},
#  {'stationCode': 1207,
#   'stationName': '富貴',
#   'stationEName': 'Fugui',
#   'stationAddrTw': '新竹縣橫山鄉豐田村中山街一段 (無站房)',
#   'stationAddrEn': 'Sec. 1, Zhongshan St. (No Station Building), Hengshan Township, Hsinchu County',
#   'stationTel': '03-5962042',
#   'gps': '24.71553 121.16729',
#   'Level': '招呼',
#   'Link': '/wiki/%E5%AF%8C%E8%B2%B4%E8%BB%8A%E7%AB%99',
#   'Open': '1962-11-28',
#   'Line': '內灣線'},
#  {'stationCode': 1208,
#   'stationName': '內灣',
#   'stationEName': 'Neiwan',
#   'stationAddrTw': '新竹縣橫山鄉內灣村中正路 6 號',
#   'stationAddrEn': 'No. 6, Zhongzheng Rd., Hengshan Township, Hsinchu County',
#   'stationTel': '03-5962042',
#   'gps': '24.70526 121.18247',
#   'Level': '乙簡',
#   'Link': '/wiki/%E5%85%A7%E7%81%A3%E8%BB%8A%E7%AB%99',
#   'Open': '1951-09-11',
#   'Line': '內灣線'},
#  {'stationCode': 1210,
#   'stationName': '新竹',
#   'stationEName': 'Hsinchu',
#   'stationAddrTw': '新竹市 東區榮光里中華路二段 445 號',
#   'stationAddrEn': 'No. 445, Sec. 2, Zhonghua Rd.,  , Hsinchu\xa0City',
#   'stationTel': '03-5237441',
#   'gps': '24.80169 120.97156',
#   'Level': '一等',
#   'Link': '/wiki/%E6%96%B0%E7%AB%B9%E8%BB%8A%E7%AB%99',
#   'Open': '1893-10-30',
#   'Line': '縱貫線、內灣線'},
#  {'stationCode': 1220,
#   'stationName': '三姓橋',
#   'stationEName': 'Sanxingqiao',
#   'stationAddrTw': '新竹市 香山區香山里元培街 32 巷 30 號',
#   'stationAddrEn': 'No. 30, Ln. 32, Yuanpei St.,  , Hsinchu\xa0City',
#   'stationTel': '03-5237441',
#   'gps': '24.78723 120.92838',
#   'Level': '簡易',
#   'Link': '/wiki/%E4%B8%89%E5%A7%93%E6%A9%8B%E8%BB%8A%E7%AB%99',
#   'Open': '2016-06-29',
#   'Line': '縱貫線'},
#  {'stationCode': 1230,
#   'stationName': '香山',
#   'stationEName': 'Xiangshan',
#   'stationAddrTw': '新竹市 香山區朝山里中華路五段 347 巷 2 弄 27 號',
#   'stationAddrEn': 'No. 27, Aly. 2, Ln. 347, Sec. 5, Zhonghua Rd.,  , Hsinchu\xa0City',
#   'stationTel': '03-5237441',
#   'gps': '24.76321 120.91391',
#   'Level': '甲簡',
#   'Link': '/wiki/%E9%A6%99%E5%B1%B1%E8%BB%8A%E7%AB%99_(%E8%87%BA%E7%81%A3)',
#   'Open': '1902-08-10',
#   'Line': '縱貫線'},
#  {'stationCode': 1240,
#   'stationName': '崎頂',
#   'stationEName': 'Qiding',
#   'stationAddrTw': '苗栗縣竹南鎮崎頂里北戶 55 號',
#   'stationAddrEn': 'No. 55, Beihu, Zhunan Township, Miaoli County',
#   'stationTel': '037-472030',
#   'gps': '24.72281 120.87213',
#   'Level': '招呼',
#   'Link': '/wiki/%E5%B4%8E%E9%A0%82%E8%BB%8A%E7%AB%99',
#   'Open': '1928-03-12',
#   'Line': '縱貫線'},
#  {'stationCode': 1250,
#   'stationName': '竹南',
#   'stationEName': 'Zhunan',
#   'stationAddrTw': '苗栗縣竹南鎮竹南里中山路 166 號',
#   'stationAddrEn': 'No. 166, Zhongshan Rd., Zhunan Township, Miaoli County',
#   'stationTel': '037-472030',
#   'gps': '24.68663 120.88041',
#   'Level': '一等',
#   'Link': '/wiki/%E7%AB%B9%E5%8D%97%E8%BB%8A%E7%AB%99',
#   'Open': '1902-08-10',
#   'Line': '縱貫線、臺中線、海岸線'},
#  {'stationCode': 2110,
#   'stationName': '談文',
#   'stationEName': 'Tanwen',
#   'stationAddrTw': '苗栗縣造橋鄉談文村仁愛路 29 號',
#   'stationAddrEn': 'No. 29, Ren’ai Rd., Zaoqiao Township, Miaoli County',
#   'stationTel': '037-472030',
#   'gps': '24.65641 120.85825',
#   'Level': '招呼',
#   'Link': '/wiki/%E8%AB%87%E6%96%87%E8%BB%8A%E7%AB%99',
#   'Open': '1922-10-11',
#   'Line': '海岸線'},
#  {'stationCode': 2120,
#   'stationName': '大山',
#   'stationEName': 'Dashan',
#   'stationAddrTw': '苗栗縣後龍鎮大山里明山路 180 號',
#   'stationAddrEn': 'No. 180, Mingshan Rd., Houlong Township, Miaoli County',
#   'stationTel': '037-728616',
#   'gps': '24.64565 120.80376',
#   'Level': '甲簡',
#   'Link': '/wiki/%E5%A4%A7%E5%B1%B1%E8%BB%8A%E7%AB%99',
#   'Open': '1922-10-11',
#   'Line': '海岸線'},
#  {'stationCode': 2130,
#   'stationName': '後龍',
#   'stationEName': 'Houlong',
#   'stationAddrTw': '苗栗縣後龍鎮北龍里車站街 127-2 號',
#   'stationAddrEn': 'No. 127, Chezhan St., Houlong Township, Miaoli County',
#   'stationTel': '037-728616',
#   'gps': '24.61621 120.78731',
#   'Level': '三等',
#   'Link': '/wiki/%E5%BE%8C%E9%BE%8D%E8%BB%8A%E7%AB%99',
#   'Open': '1922-10-11',
#   'Line': '海岸線'},
#  {'stationCode': 2140,
#   'stationName': '龍港',
#   'stationEName': 'Longgang',
#   'stationAddrTw': '苗栗縣後龍鎮龍京里公司寮 85 號',
#   'stationAddrEn': 'No. 85, Gongsiliao, Houlong Township, Miaoli County',
#   'stationTel': '037-728616',
#   'gps': '24.61169 120.75812',
#   'Level': '招呼',
#   'Link': '/wiki/%E9%BE%8D%E6%B8%AF%E8%BB%8A%E7%AB%99',
#   'Open': '1922-10-11',
#   'Line': '海岸線'},
#  {'stationCode': 2150,
#   'stationName': '白沙屯',
#   'stationEName': 'Baishatun',
#   'stationAddrTw': '苗栗縣通霄鎮白西里白西 131 號',
#   'stationAddrEn': 'No. 131, Baixi, Tongxiao Township, Miaoli County',
#   'stationTel': '037-793066',
#   'gps': '24.56481 120.70824',
#   'Level': '三等',
#   'Link': '/wiki/%E7%99%BD%E6%B2%99%E5%B1%AF%E8%BB%8A%E7%AB%99',
#   'Open': '1922-10-11',
#   'Line': '海岸線'},
#  {'stationCode': 2160,
#   'stationName': '新埔',
#   'stationEName': 'Xinpu',
#   'stationAddrTw': '苗栗縣通霄鎮新埔里新埔 57 號',
#   'stationAddrEn': 'No. 57, Xinpu, Tongxiao Township, Miaoli County',
#   'stationTel': '037-793066',
#   'gps': '24.54018 120.69518',
#   'Level': '乙簡',
#   'Link': '/wiki/%E6%96%B0%E5%9F%94%E8%BB%8A%E7%AB%99_(%E8%8B%97%E6%A0%97%E7%B8%A3)',
#   'Open': '1922-10-11',
#   'Line': '海岸線'},
#  {'stationCode': 2170,
#   'stationName': '通霄',
#   'stationEName': 'Tongxiao',
#   'stationAddrTw': '苗栗縣通霄鎮通西里中正路 109 號',
#   'stationAddrEn': 'No. 109, Zhongzhen Rd., Tongxiao Township, Miaoli County',
#   'stationTel': '037-758300',
#   'gps': '24.49141 120.67843',
#   'Level': '三等',
#   'Link': '/wiki/%E9%80%9A%E9%9C%84%E8%BB%8A%E7%AB%99',
#   'Open': '1922-10-11',
#   'Line': '海岸線'},
#  {'stationCode': 2180,
#   'stationName': '苑裡',
#   'stationEName': 'Yuanli',
#   'stationAddrTw': '苗栗縣苑裡鎮苑北里中山路 165 號',
#   'stationAddrEn': 'No. 165, Zhongshan Rd., Yuanli Township, Miaoli County',
#   'stationTel': '037-851013',
#   'gps': '24.44344 120.65146',
#   'Level': '三等',
#   'Link': '/wiki/%E8%8B%91%E8%A3%A1%E8%BB%8A%E7%AB%99',
#   'Open': '1922-10-11',
#   'Line': '海岸線'},
#  {'stationCode': 2190,
#   'stationName': '日南',
#   'stationEName': 'Rinan',
#   'stationAddrTw': '臺中市大甲區孟春里中山路二段 140 巷 8 號',
#   'stationAddrEn': 'No. 8, Ln. 140, Sec. 2, Zhongshan Rd., Dajia Dist., Taichung City',
#   'stationTel': '04-26816113',
#   'gps': '24.37805 120.65412',
#   'Level': '乙簡',
#   'Link': '/wiki/%E6%97%A5%E5%8D%97%E8%BB%8A%E7%AB%99',
#   'Open': '1922-10-11',
#   'Line': '海岸線'},
#  {'stationCode': 2200,
#   'stationName': '大甲',
#   'stationEName': 'Dajia',
#   'stationAddrTw': '臺中市大甲區大甲里中山路一段 828 號',
#   'stationAddrEn': 'No. 828, Sec. 1, Zhongshan Rd., Dajia Dist., Taichung City',
#   'stationTel': '04-26872022',
#   'gps': '24.34448 120.62702',
#   'Level': '二等',
#   'Link': '/wiki/%E5%A4%A7%E7%94%B2%E8%BB%8A%E7%AB%99',
#   'Open': '1922-10-11',
#   'Line': '海岸線'},
#  {'stationCode': 2210,
#   'stationName': '臺中港',
#   'stationEName': 'Taichung Port',
#   'stationAddrTw': '臺中市清水區頂湳里甲南路 2 號',
#   'stationAddrEn': 'No. 2, Jianan Rd., Qingshui Dist., Taichung City',
#   'stationTel': '04-26225374',
#   'gps': '24.30441 120.60231',
#   'Level': '二等',
#   'Link': '/wiki/%E5%8F%B0%E4%B8%AD%E6%B8%AF%E8%BB%8A%E7%AB%99',
#   'Open': '1922-10-11',
#   'Line': '海岸線、台中港線'},
#  {'stationCode': 2220,
#   'stationName': '清水',
#   'stationEName': 'Qingshui',
#   'stationAddrTw': '臺中市南社里中正街 115 號',
#   'stationAddrEn': 'No. 115, Zhongzheng St., , Taichung City',
#   'stationTel': '04-26222021',
#   'gps': '24.26364 120.56918',
#   'Level': '三等',
#   'Link': '/wiki/%E6%B8%85%E6%B0%B4%E8%BB%8A%E7%AB%99_(%E5%8F%B0%E7%81%A3)',
#   'Open': '1920-12-25',
#   'Line': '海岸線'},
#  {'stationCode': 2230,
#   'stationName': '沙鹿',
#   'stationEName': 'Shalu',
#   'stationAddrTw': '臺中市沙鹿區沙鹿里中正街 94 號',
#   'stationAddrEn': 'No. 94, Zhongzheng St., Shalu Dist., Taichung City',
#   'stationTel': '04-26625057',
#   'gps': '24.23702 120.55752',
#   'Level': '二等',
#   'Link': '/wiki/%E6%B2%99%E9%B9%BF%E8%BB%8A%E7%AB%99',
#   'Open': '1920-12-25',
#   'Line': '海岸線、藍線（綜合規劃由交通部審核中）'},
#  {'stationCode': 2240,
#   'stationName': '龍井',
#   'stationEName': 'Longjing',
#   'stationAddrTw': '臺中市龍井區龍泉里龍新路 1 號',
#   'stationAddrEn': 'No. 1, Longxin Rd., Longjing Dist., Taichung City',
#   'stationTel': '04-26355578',
#   'gps': '24.19745 120.54336',
#   'Level': '三等',
#   'Link': '/wiki/%E9%BE%8D%E4%BA%95%E8%BB%8A%E7%AB%99',
#   'Open': '1920-12-25',
#   'Line': '海岸線'},
#  {'stationCode': 2250,
#   'stationName': '大肚',
#   'stationEName': 'Dadu',
#   'stationAddrTw': '臺中市大肚區頂街里平和街 121 號',
#   'stationAddrEn': 'No. 121, Pinghe St., Dadu Dist., Taichung City',
#   'stationTel': '04-26992523',
#   'gps': '24.15401 120.54255',
#   'Level': '三等',
#   'Link': '/wiki/%E5%A4%A7%E8%82%9A%E8%BB%8A%E7%AB%99',
#   'Open': '1920-12-25',
#   'Line': '海岸線'},
#  {'stationCode': 2260,
#   'stationName': '追分',
#   'stationEName': 'Zhuifen',
#   'stationAddrTw': '臺中市大肚區王田里追分街 13 號',
#   'stationAddrEn': 'No. 13, Zhuifen St., Dadu Dist., Taichung City',
#   'stationTel': '04-26933106',
#   'gps': '24.12061 120.57014',
#   'Level': '三等',
#   'Link': '/wiki/%E8%BF%BD%E5%88%86%E8%BB%8A%E7%AB%99',
#   'Open': '1922-10-11',
#   'Line': '海岸線、成追線'},
#  {'stationCode': 3140,
#   'stationName': '造橋',
#   'stationEName': 'Zaoqiao',
#   'stationAddrTw': '苗栗縣造橋鄉造橋村平仁路 54 號',
#   'stationAddrEn': 'No. 54, Pingren Rd., Zaoqiao Township, Miaoli County',
#   'stationTel': '037-472030',
#   'gps': '24.64206 120.86719',
#   'Level': '招呼',
#   'Link': '/wiki/%E9%80%A0%E6%A9%8B%E8%BB%8A%E7%AB%99',
#   'Open': '1903-05-25',
#   'Line': '臺中線'},
#  {'stationCode': 3150,
#   'stationName': '豐富',
#   'stationEName': 'Fengfu',
#   'stationAddrTw': '苗栗縣後龍鎮校椅里高鐵一路 66 號',
#   'stationAddrEn': 'No. 66, Gaotie 1st Rd., Houlong Township, Miaoli County',
#   'stationTel': '037-726700',
#   'gps': '24.60131 120.82357',
#   'Level': '簡易',
#   'Link': '/wiki/%E8%B1%90%E5%AF%8C%E8%BB%8A%E7%AB%99',
#   'Open': '1903-05-25',
#   'Line': '臺中線'},
#  {'stationCode': 3160,
#   'stationName': '苗栗',
#   'stationEName': 'Miaoli',
#   'stationAddrTw': '苗栗縣上苗里為公路 1 號',
#   'stationAddrEn': 'No. 1, Weigong Rd., , Miaoli County',
#   'stationTel': '037-260031',
#   'gps': '24.57002 120.82264',
#   'Level': '一等',
#   'Link': '/wiki/%E8%8B%97%E6%A0%97%E8%BB%8A%E7%AB%99',
#   'Open': '1903-05-25',
#   'Line': '臺中線'},
#  {'stationCode': 3170,
#   'stationName': '南勢',
#   'stationEName': 'Nanshi',
#   'stationAddrTw': '苗栗縣苗栗市新英里南勢 39 號',
#   'stationAddrEn': 'No. 39, Nanshi, Miaoli City, Miaoli County',
#   'stationTel': '037-260031',
#   'gps': '24.52234 120.79157',
#   'Level': '招呼',
#   'Link': '/wiki/%E5%8D%97%E5%8B%A2%E8%BB%8A%E7%AB%99',
#   'Open': '1903-07-01',
#   'Line': '臺中線'},
#  {'stationCode': 3180,
#   'stationName': '銅鑼',
#   'stationEName': 'Tongluo',
#   'stationAddrTw': '苗栗縣銅鑼鄉銅鑼村大同路 13 號',
#   'stationAddrEn': 'No. 13, Datong Rd., Tongluo Township, Miaoli County',
#   'stationTel': '037-983838',
#   'gps': '24.48648 120.78616',
#   'Level': '三等',
#   'Link': '/wiki/%E9%8A%85%E9%91%BC%E8%BB%8A%E7%AB%99',
#   'Open': '1903-10-07',
#   'Line': '臺中線'},
#  {'stationCode': 3190,
#   'stationName': '三義',
#   'stationEName': 'Sanyi',
#   'stationAddrTw': '苗栗縣三義鄉雙湖村雙湖 90 號',
#   'stationAddrEn': 'No. 90, Shuanghu, Sanyi Township, Miaoli County',
#   'stationTel': '037-874763',
#   'gps': '24.42066 120.77393',
#   'Level': '三等',
#   'Link': '/wiki/%E4%B8%89%E7%BE%A9%E8%BB%8A%E7%AB%99',
#   'Open': '1903-10-07',
#   'Line': '臺中線、舊山線'},
#  {'stationCode': 3210,
#   'stationName': '泰安',
#   'stationEName': "Tai'an",
#   'stationAddrTw': '臺中市后里區泰安里安眉路 37 之 12 號',
#   'stationAddrEn': 'No. 37-12, Anmei Rd., Houli Dist., Taichung City',
#   'stationTel': '04-25586540',
#   'gps': '24.33146 120.74181',
#   'Level': '簡易',
#   'Link': '/wiki/%E6%B3%B0%E5%AE%89%E8%BB%8A%E7%AB%99_(%E5%8F%B0%E4%B8%AD%E7%B7%9A)',
#   'Open': '1998-09-24',
#   'Line': '臺中線'},
#  {'stationCode': 3220,
#   'stationName': '后里',
#   'stationEName': 'Houli',
#   'stationAddrTw': '臺中市后里區義里里甲后路一段 1 號',
#   'stationAddrEn': 'No. 1, Jiahou Rd., Houli Dist., Taichung City',
#   'stationTel': '04-25562038',
#   'gps': '24.30933 120.73288',
#   'Level': '三等',
#   'Link': '/wiki/%E5%90%8E%E9%87%8C%E8%BB%8A%E7%AB%99',
#   'Open': '1905-05-15',
#   'Line': '臺中線'},
#  {'stationCode': 3230,
#   'stationName': '豐原',
#   'stationEName': 'Fengyuan',
#   'stationAddrTw': '臺中市豐原區豐原里中正路 1 號',
#   'stationAddrEn': 'No. 1, Zhongzheng Rd., Fengyuan Dist., Taichung City',
#   'stationTel': '04-25207950#32',
#   'gps': '24.25413 120.72291',
#   'Level': '一等',
#   'Link': '/wiki/%E8%B1%90%E5%8E%9F%E8%BB%8A%E7%AB%99',
#   'Open': '1905-05-15',
#   'Line': '臺中線'},
#  {'stationCode': 3240,
#   'stationName': '栗林',
#   'stationEName': 'Lilin',
#   'stationAddrTw': '臺中市潭子區潭豐路二段747號',
#   'stationAddrEn': 'No. 747, Section 2, Tanfeng Road, Tanzi Dist., Taichung City',
#   'stationTel': '04-25391401',
#   'gps': '24.23481 120.71069',
#   'Level': '簡易',
#   'Link': '/wiki/%E6%A0%97%E6%9E%97%E8%BB%8A%E7%AB%99_(%E8%87%BA%E7%81%A3)',
#   'Open': '2018-10-28',
#   'Line': '臺中線'},
#  {'stationCode': 3250,
#   'stationName': '潭子',
#   'stationEName': 'Tanzi',
#   'stationAddrTw': '臺中市潭子區中山路二段352-1號',
#   'stationAddrEn': 'No. 352-1, Sec. 2, Zhongshan Rd., Tanzi Dist., Taichung City',
#   'stationTel': '04-25363852',
#   'gps': '24.21283 120.70557',
#   'Level': '三等',
#   'Link': '/wiki/%E6%BD%AD%E5%AD%90%E8%BB%8A%E7%AB%99',
#   'Open': '1905-05-15',
#   'Line': '臺中線'},
#  {'stationCode': 3260,
#   'stationName': '頭家厝',
#   'stationEName': 'Toujiacuo',
#   'stationAddrTw': '臺中市潭子區頭張東路43巷8號',
#   'stationAddrEn': 'No. 8, Ln. 43, Touzhang E. Rd., Tanzi Dist., Taichung City',
#   'stationTel': '04-25391426',
#   'gps': '24.19572 120.70398',
#   'Level': '簡易',
#   'Link': '/wiki/%E9%A0%AD%E5%AE%B6%E5%8E%9D%E8%BB%8A%E7%AB%99',
#   'Open': '2018-10-28',
#   'Line': '臺中線'},
#  {'stationCode': 3270,
#   'stationName': '松竹',
#   'stationEName': 'Songzhu',
#   'stationAddrTw': '臺中市北屯區舊社里松竹路一段1473巷100號',
#   'stationAddrEn': 'No. 100, Ln. 1473, Sec. 1, Songzhu Rd., Taiwan (R.O.C.), Beitun Dist., Taichung City',
#   'stationTel': '04-22473033',
#   'gps': '24.17983 120.70197',
#   'Level': '簡易',
#   'Link': '/wiki/%E6%9D%BE%E7%AB%B9%E8%BB%8A%E7%AB%99',
#   'Open': '2018-10-28',
#   'Line': '臺中線'},
#  {'stationCode': 3280,
#   'stationName': '太原',
#   'stationEName': 'Taiyuan',
#   'stationAddrTw': '臺中市北屯區北興里東光路 665 號',
#   'stationAddrEn': 'No. 665, Dongguang Rd., Beitun Dist., Taichung City',
#   'stationTel': '04-22313926',
#   'gps': '24.16413 120.69981',
#   'Level': '乙簡',
#   'Link': '/wiki/%E5%A4%AA%E5%8E%9F%E8%BB%8A%E7%AB%99',
#   'Open': '2002-11-22',
#   'Line': '臺中線'},
#  {'stationCode': 3290,
#   'stationName': '精武',
#   'stationEName': 'Jingwu',
#   'stationAddrTw': '臺中市東區東南里東光路 161號',
#   'stationAddrEn': 'No. 161, Dongguang Rd., Taiwan (R.O.C.)No. 194, Dongguang Rd., East Dist., Taichung City',
#   'stationTel': '04-23606501',
#   'gps': '24.14917 120.69773',
#   'Level': '簡易',
#   'Link': '/wiki/%E7%B2%BE%E6%AD%A6%E8%BB%8A%E7%AB%99',
#   'Open': '2018-10-28',
#   'Line': '臺中線'},
#  {'stationCode': 3300,
#   'stationName': '臺中',
#   'stationEName': 'Taichung',
#   'stationAddrTw': '臺中市中區綠川里臺灣大道一段 1 號',
#   'stationAddrEn': 'No. 1, Sec. 1, Taiwan Blvd., Central Dist., Taichung City',
#   'stationTel': '04-22216492',
#   'gps': '24.13661 120.68527',
#   'Level': '特等',
#   'Link': '/wiki/%E8%87%BA%E4%B8%AD%E8%BB%8A%E7%AB%99',
#   'Open': '1905-05-15',
#   'Line': '臺中線'},
#  {'stationCode': 3310,
#   'stationName': '五權',
#   'stationEName': 'Wuquan',
#   'stationAddrTw': '臺中市南區建國南路二段201號',
#   'stationAddrEn': 'No. 201, Sec. 2, Jianguo S. Rd., Taiwan (R.O.C.), South Dist., Taichung City',
#   'stationTel': '04-22601636',
#   'gps': '24.12877 120.66644',
#   'Level': '簡易',
#   'Link': '/wiki/%E4%BA%94%E6%AC%8A%E8%BB%8A%E7%AB%99',
#   'Open': '2018-10-28',
#   'Line': '臺中線'},
#  {'stationCode': 3320,
#   'stationName': '大慶',
#   'stationEName': 'Daqing',
#   'stationAddrTw': '臺中市南區樹德里7鄰大慶街2段130號',
#   'stationAddrEn': 'No. 130, Sec. 2, Daqing St., Taiwan (R.O.C.), South Dist., Taichung City',
#   'stationTel': '04-22637940',
#   'gps': '24.11891 120.64791',
#   'Level': '簡易',
#   'Link': '/wiki/%E5%A4%A7%E6%85%B6%E8%BB%8A%E7%AB%99',
#   'Open': '1998-07-07',
#   'Line': '臺中線'},
#  {'stationCode': 3330,
#   'stationName': '烏日',
#   'stationEName': 'Wuri',
#   'stationAddrTw': '臺中市烏日區烏日里三民街 258 號',
#   'stationAddrEn': 'No. 258, Sanmin St., Wuri Dist., Taichung City',
#   'stationTel': '04-23381071',
#   'gps': '24.10867 120.62244',
#   'Level': '簡易',
#   'Link': '/wiki/%E7%83%8F%E6%97%A5%E8%BB%8A%E7%AB%99',
#   'Open': '1905-05-15',
#   'Line': '臺中線'},
#  {'stationCode': 3340,
#   'stationName': '新烏日',
#   'stationEName': 'Xinwuri',
#   'stationAddrTw': '臺中市烏日區三和里高鐵東一路 26 號',
#   'stationAddrEn': 'No. 26, Gaotie E. 1st Rd., Wuri Dist., Taichung City',
#   'stationTel': '04-23376883',
#   'gps': '24.10976 120.61429',
#   'Level': '二等',
#   'Link': '/wiki/%E6%96%B0%E7%83%8F%E6%97%A5%E8%BB%8A%E7%AB%99',
#   'Open': '2006-12-01',
#   'Line': '臺中線'},
#  {'stationCode': 3350,
#   'stationName': '成功',
#   'stationEName': 'Chenggong',
#   'stationAddrTw': '臺中市烏日區榮泉里中山路三段 550 號',
#   'stationAddrEn': 'No. 550, Sec. 3, Zhongshan Rd., Wuri Dist., Taichung City',
#   'stationTel': '04-23371986',
#   'gps': '24.11424 120.59021',
#   'Level': '三等',
#   'Link': '/wiki/%E6%88%90%E5%8A%9F%E8%BB%8A%E7%AB%99',
#   'Open': '1905-05-15',
#   'Line': '臺中線、成追線'},
#  {'stationCode': 3360,
#   'stationName': '彰化',
#   'stationEName': 'Changhua',
#   'stationAddrTw': '彰化縣彰化市長樂里三民路 1 號',
#   'stationAddrEn': 'No. 1, Sanmin Rd., Zhanghua City, Changhua County',
#   'stationTel': '04-7274218#11',
#   'gps': '24.08171 120.53828',
#   'Level': '一等',
#   'Link': '/wiki/%E5%BD%B0%E5%8C%96%E8%BB%8A%E7%AB%99',
#   'Open': '1905-03-26',
#   'Line': '臺中線海岸線縱貫線南段'},
#  {'stationCode': 3370,
#   'stationName': '花壇',
#   'stationEName': 'Huatan',
#   'stationAddrTw': '彰化縣花壇鄉花壇村中正路 370 號',
#   'stationAddrEn': 'No. 370, Zhongzheng Rd., Huatan Township, Changhua County',
#   'stationTel': '04-7881418',
#   'gps': '24.02521 120.53759',
#   'Level': '乙簡',
#   'Link': '/wiki/%E8%8A%B1%E5%A3%87%E8%BB%8A%E7%AB%99',
#   'Open': '1905-03-26',
#   'Line': '縱貫線南段'},
#  {'stationCode': 3380,
#   'stationName': '大村',
#   'stationEName': 'Dacun',
#   'stationAddrTw': '彰化縣大村鄉過溝村福進路 100 號',
#   'stationAddrEn': 'No. 100, Fujin Rd., Dacun Township, Changhua County',
#   'stationTel': '04-8525148',
#   'gps': '23.99003 120.56068',
#   'Level': '簡易',
#   'Link': '/wiki/%E5%A4%A7%E6%9D%91%E8%BB%8A%E7%AB%99',
#   'Open': '2006-04-04',
#   'Line': '縱貫線南段'},
#  {'stationCode': 3390,
#   'stationName': '員林',
#   'stationEName': 'Yuanlin',
#   'stationAddrTw': '彰化縣員林市和平里民權街 55 號',
#   'stationAddrEn': 'No. 55, Minquan St., Yuanlin City, Changhua County',
#   'stationTel': '04-8320544#15',
#   'gps': '23.95933 120.56995',
#   'Level': '一等',
#   'Link': '/wiki/%E5%93%A1%E6%9E%97%E8%BB%8A%E7%AB%99',
#   'Open': '1905-03-26',
#   'Line': '縱貫線南段'},
#  {'stationCode': 3400,
#   'stationName': '永靖',
#   'stationEName': 'Yongjing',
#   'stationAddrTw': '彰化縣永靖鄉崙子村永崙路 25 號',
#   'stationAddrEn': 'No. 25, Yonglun Rd., Yongjing Township, Changhua County',
#   'stationTel': '04-8320544#15',
#   'gps': '23.92811 120.57165',
#   'Level': '招呼',
#   'Link': '/wiki/%E6%B0%B8%E9%9D%96%E8%BB%8A%E7%AB%99',
#   'Open': '1958-10-24',
#   'Line': '縱貫線南段'},
#  {'stationCode': 3410,
#   'stationName': '社頭',
#   'stationEName': 'Shetou',
#   'stationAddrTw': '彰化縣社頭鄉廣興村社站路 10 號',
#   'stationAddrEn': 'No. 10, Shezhan Rd., Shetou Township, Changhua County',
#   'stationTel': '04-8711646',
#   'gps': '23.89571 120.58082',
#   'Level': '三等',
#   'Link': '/wiki/%E7%A4%BE%E9%A0%AD%E8%BB%8A%E7%AB%99',
#   'Open': '1905-03-26',
#   'Line': '縱貫線南段'},
#  {'stationCode': 3420,
#   'stationName': '田中',
#   'stationEName': 'Tianzhong',
#   'stationAddrTw': '彰化縣田中鎮中路里中州路一段 1 號',
#   'stationAddrEn': 'No. 1, Sec. 1, Zhongzhou Rd., Tianzhong Township, Changhua County',
#   'stationTel': '04-8742142',
#   'gps': '23.85827 120.59121',
#   'Level': '二等',
#   'Link': '/wiki/%E7%94%B0%E4%B8%AD%E8%BB%8A%E7%AB%99',
#   'Open': '1905-03-26',
#   'Line': '縱貫線南段'},
#  {'stationCode': 3430,
#   'stationName': '二水',
#   'stationEName': 'Ershui',
#   'stationAddrTw': '彰化縣二水鄉光化村光文路 1 號',
#   'stationAddrEn': 'No. 1, Guangwen Rd., Ershui Township, Changhua County',
#   'stationTel': '04-8792027',
#   'gps': '23.81321 120.61805',
#   'Level': '二等',
#   'Link': '/wiki/%E4%BA%8C%E6%B0%B4%E8%BB%8A%E7%AB%99',
#   'Open': '1905-01-15',
#   'Line': '縱貫線南段、集集線'},
#  {'stationCode': 3431,
#   'stationName': '源泉',
#   'stationEName': 'Yuanquan',
#   'stationAddrTw': '彰化縣二水鄉合興村英義路 (無站房)',
#   'stationAddrEn': 'Yingyi Rd. (No Station Building), Ershui Township, Changhua County',
#   'stationTel': '04-8792027',
#   'gps': '23.79846 120.64208',
#   'Level': '招呼',
#   'Link': '/wiki/%E6%BA%90%E6%B3%89%E8%BB%8A%E7%AB%99',
#   'Open': '1922-01-14',
#   'Line': '集集線'},
#  {'stationCode': 3432,
#   'stationName': '濁水',
#   'stationEName': 'Zhuoshui',
#   'stationAddrTw': '南投縣名間鄉濁水村車站路 15 號',
#   'stationAddrEn': 'No. 15, Chezhan Rd., Mingjian Township, Nantou County',
#   'stationTel': '049-2735850',
#   'gps': '23.83467 120.70467',
#   'Level': '丙簡',
#   'Link': '/wiki/%E6%BF%81%E6%B0%B4%E8%BB%8A%E7%AB%99',
#   'Open': '1922-01-14',
#   'Line': '集集線'},
#  {'stationCode': 3433,
#   'stationName': '龍泉',
#   'stationEName': 'Longquan',
#   'stationAddrTw': '南投縣集集鎮隘寮村龍泉巷 (無站房)',
#   'stationAddrEn': 'Longquan Ln. (No Station Building), Jiji Township, Nantou County',
#   'stationTel': '04-8792027',
#   'gps': '23.83521 120.74996',
#   'Level': '招呼',
#   'Link': '/wiki/%E9%BE%8D%E6%B3%89%E8%BB%8A%E7%AB%99',
#   'Open': '1922-01-14',
#   'Line': '集集線'},
#  {'stationCode': 3434,
#   'stationName': '集集',
#   'stationEName': 'Jiji',
#   'stationAddrTw': '南投縣集集鎮吳厝里民生路 75 號',
#   'stationAddrEn': 'No. 75, Minsheng Rd., Jiji Township, Nantou County',
#   'stationTel': '049-2762546',
#   'gps': '23.82653 120.78491',
#   'Level': '招呼',
#   'Link': '/wiki/%E9%9B%86%E9%9B%86%E8%BB%8A%E7%AB%99',
#   'Open': '1922-01-14',
#   'Line': '集集線'},
#  {'stationCode': 3435,
#   'stationName': '水里',
#   'stationEName': 'Shuili',
#   'stationAddrTw': '南投縣水里鄉水里村民生路 440 號',
#   'stationAddrEn': 'No. 440, Minsheng Rd., Shuili Township, Nantou County',
#   'stationTel': '049-2770015',
#   'gps': '23.81844 120.85333',
#   'Level': '簡易',
#   'Link': '/wiki/%E6%B0%B4%E9%87%8C%E8%BB%8A%E7%AB%99',
#   'Open': '1922-01-14',
#   'Line': '集集線'},
#  {'stationCode': 3436,
#   'stationName': '車埕',
#   'stationEName': 'Checheng',
#   'stationAddrTw': '南投縣水里鄉車埕村民權巷 2 號',
#   'stationAddrEn': 'No. 2, Minquan Ln., Shuili Township, Nantou County',
#   'stationTel': '049-2774749',
#   'gps': '23.83263 120.86572',
#   'Level': '招呼',
#   'Link': '/wiki/%E8%BB%8A%E5%9F%95%E8%BB%8A%E7%AB%99',
#   'Open': '1922-01-14',
#   'Line': '集集線'},
#  {'stationCode': 3450,
#   'stationName': '林內',
#   'stationEName': 'Linnei',
#   'stationAddrTw': '雲林縣林內鄉林中村中山路 42 號',
#   'stationAddrEn': 'No. 42, Zhongshan Rd., Linnei Township, Yunlin County',
#   'stationTel': '05-5892040',
#   'gps': '23.75967 120.61499',
#   'Level': '三等',
#   'Link': '/wiki/%E6%9E%97%E5%85%A7%E8%BB%8A%E7%AB%99',
#   'Open': '1907-06-20',
#   'Line': '縱貫線南段'},
#  {'stationCode': 3460,
#   'stationName': '石榴',
#   'stationEName': 'Shiliu',
#   'stationAddrTw': '雲林縣斗六市榴北里文明路 31 號',
#   'stationAddrEn': 'No. 31, Wenming Rd., Douliu City, Yunlin County',
#   'stationTel': '05-5332900',
#   'gps': '23.73167 120.57998',
#   'Level': '招呼',
#   'Link': '/wiki/%E7%9F%B3%E6%A6%B4%E8%BB%8A%E7%AB%99',
#   'Open': '1905-10-15',
#   'Line': '縱貫線南段'},
#  {'stationCode': 3470,
#   'stationName': '斗六',
#   'stationEName': 'Douliu',
#   'stationAddrTw': '雲林縣斗六市信義里民生路 187 號',
#   'stationAddrEn': 'No. 187, Minsheng Rd., Douliu City, Yunlin County',
#   'stationTel': '05-5332900',
#   'gps': '23.71157 120.54117',
#   'Level': '一等',
#   'Link': '/wiki/%E6%96%97%E5%85%AD%E8%BB%8A%E7%AB%99',
#   'Open': '1904-02-01',
#   'Line': '縱貫線南段'},
#  {'stationCode': 3480,
#   'stationName': '斗南',
#   'stationEName': 'Dounan',
#   'stationAddrTw': '雲林縣斗南鎮南昌里中山路 2 號',
#   'stationAddrEn': 'No. 2, Zhongshan Rd., Dounan Township, Yunlin County',
#   'stationTel': '05-5972039',
#   'gps': '23.67302 120.48082',
#   'Level': '二等',
#   'Link': '/wiki/%E6%96%97%E5%8D%97%E8%BB%8A%E7%AB%99',
#   'Open': '1903-12-15',
#   'Line': '縱貫線南段'},
#  {'stationCode': 3490,
#   'stationName': '石龜',
#   'stationEName': 'Shigui',
#   'stationAddrTw': '雲林縣斗南鎮石龜里',
#   'stationAddrEn': 'Shigui Vil., Dounan Township, Yunlin County',
#   'stationTel': '05-5972039',
#   'gps': '23.63951 120.47106',
#   'Level': '招呼',
#   'Link': '/wiki/%E7%9F%B3%E9%BE%9C%E8%BB%8A%E7%AB%99',
#   'Open': '1958-10-24',
#   'Line': '縱貫線南段'},
#  {'stationCode': 4050,
#   'stationName': '大林',
#   'stationEName': 'Dalin',
#   'stationAddrTw': '嘉義縣大林鎮吉林里中山路 2 號',
#   'stationAddrEn': 'No. 2, Zhongshan Rd., Dalin Township, Chiayi County',
#   'stationTel': '05-2654804',
#   'gps': '23.60112 120.45585',
#   'Level': '三等',
#   'Link': '/wiki/%E5%A4%A7%E6%9E%97%E8%BB%8A%E7%AB%99',
#   'Open': '1903-12-15',
#   'Line': '縱貫線南段'},
#  {'stationCode': 4060,
#   'stationName': '民雄',
#   'stationEName': 'Minxiong',
#   'stationAddrTw': '嘉義縣民雄鄉東榮村和平路 2 號',
#   'stationAddrEn': 'No. 2, Heping Rd., Minxiong Township, Chiayi County',
#   'stationTel': '05-2264272',
#   'gps': '23.55502 120.43136',
#   'Level': '三等',
#   'Link': '/wiki/%E6%B0%91%E9%9B%84%E8%BB%8A%E7%AB%99',
#   'Open': '1903-12-15',
#   'Line': '縱貫線南段'},
#  {'stationCode': 4070,
#   'stationName': '嘉北',
#   'stationEName': 'Jiabei',
#   'stationAddrTw': '嘉義市 東區後湖里保建街 110 號',
#   'stationAddrEn': 'No. 110, Baojian St.,  , Chiayi City',
#   'stationTel': '05-2334584',
#   'gps': '23.49985 120.44852',
#   'Level': '簡易',
#   'Link': '/wiki/%E5%98%89%E5%8C%97%E8%BB%8A%E7%AB%99',
#   'Open': '2005-09-08',
#   'Line': '縱貫線南段'},
#  {'stationCode': 4080,
#   'stationName': '嘉義',
#   'stationEName': 'Chiayi',
#   'stationAddrTw': '嘉義市 西區番社里中山路 528 號',
#   'stationAddrEn': 'No. 528, Zhongshan Rd.,  , Chiayi City',
#   'stationTel': '05-2228904',
#   'gps': '23.47902 120.44124',
#   'Level': '一等',
#   'Link': '/wiki/%E5%98%89%E7%BE%A9%E8%BB%8A%E7%AB%99',
#   'Open': '1902-04-20',
#   'Line': '縱貫線、阿里山線'},
#  {'stationCode': 4090,
#   'stationName': '水上',
#   'stationEName': 'Shuishang',
#   'stationAddrTw': '嘉義縣水上鄉下寮村鴿溪寮 49 號',
#   'stationAddrEn': 'No. 49, Gexiliao, Shuishang Township, Chiayi County',
#   'stationTel': '05-2228904',
#   'gps': '23.43389 120.39961',
#   'Level': '簡易',
#   'Link': '/wiki/%E6%B0%B4%E4%B8%8A%E8%BB%8A%E7%AB%99',
#   'Open': '1902-04-20',
#   'Line': '縱貫線'},
#  {'stationCode': 4100,
#   'stationName': '南靖',
#   'stationEName': 'Nanjing',
#   'stationAddrTw': '嘉義縣水上鄉三鎮村三鎮路 26 號',
#   'stationAddrEn': 'No. 26, Sanzhen Rd., Shuishang Township, Chiayi County',
#   'stationTel': '05-2601232',
#   'gps': '23.41346 120.38647',
#   'Level': '甲簡',
#   'Link': '/wiki/%E5%8D%97%E9%9D%96%E8%BB%8A%E7%AB%99',
#   'Open': '1911-03-20',
#   'Line': '縱貫線'},
#  {'stationCode': 4110,
#   'stationName': '後壁',
#   'stationEName': 'Houbi',
#   'stationAddrTw': '臺南市後壁區後壁里後壁 77 號',
#   'stationAddrEn': 'No. 77, Houbi, Houbi Dist., Tainan City',
#   'stationTel': '06-6872055',
#   'gps': '23.36626 120.36058',
#   'Level': '甲簡',
#   'Link': '/wiki/%E5%BE%8C%E5%A3%81%E8%BB%8A%E7%AB%99',
#   'Open': '1903-04-20',
#   'Line': '縱貫線'},
#  {'stationCode': 4120,
#   'stationName': '新營',
#   'stationEName': 'Xinying',
#   'stationAddrTw': '臺南市新營區中營里中山路 1 號',
#   'stationAddrEn': 'No. 1, Zhongshan Rd., Xinying Dist., Tainan City',
#   'stationTel': '06-6322104',
#   'gps': '23.30658 120.32344',
#   'Level': '一等',
#   'Link': '/wiki/%E6%96%B0%E7%87%9F%E8%BB%8A%E7%AB%99',
#   'Open': '1901-12-16',
#   'Line': '縱貫線'},
#  {'stationCode': 4130,
#   'stationName': '柳營',
#   'stationEName': 'Liuying',
#   'stationAddrTw': '臺南市柳營區東昇里建國路 1 號',
#   'stationAddrEn': 'No. 1, Jianguo Rd., Liuying Dist., Tainan City',
#   'stationTel': '06-6226450',
#   'gps': '23.27762 120.32252',
#   'Level': '簡易',
#   'Link': '/wiki/%E6%9F%B3%E7%87%9F%E8%BB%8A%E7%AB%99',
#   'Open': '1960-06-01',
#   'Line': '縱貫線'},
#  {'stationCode': 4140,
#   'stationName': '林鳳營',
#   'stationEName': 'Linfengying',
#   'stationAddrTw': '臺南市六甲區中社里林鳳營 16 號',
#   'stationAddrEn': 'No. 16, Linfengying, Liujia Dist., Tainan City',
#   'stationTel': '06-6986086',
#   'gps': '23.24259 120.32107',
#   'Level': '甲簡',
#   'Link': '/wiki/%E6%9E%97%E9%B3%B3%E7%87%9F%E8%BB%8A%E7%AB%99',
#   'Open': '1901-12-16',
#   'Line': '縱貫線'},
#  {'stationCode': 4150,
#   'stationName': '隆田',
#   'stationEName': 'Longtian',
#   'stationAddrTw': '臺南市官田區隆田里中山路一段 1 號',
#   'stationAddrEn': 'No. 1, Sec. 1, Zhongshan Rd., Guantian Dist., Tainan City',
#   'stationTel': '06-5791664',
#   'gps': '23.19271 120.31917',
#   'Level': '二等',
#   'Link': '/wiki/%E9%9A%86%E7%94%B0%E8%BB%8A%E7%AB%99',
#   'Open': '1902-04-20',
#   'Line': '縱貫線'},
#  {'stationCode': 4160,
#   'stationName': '拔林',
#   'stationEName': 'Balin',
#   'stationAddrTw': '臺南市官田區拔林里拔子林 83 之 1 號',
#   'stationAddrEn': 'No. 83-1, Bazilin, Guantian Dist., Tainan City',
#   'stationTel': '06-5791664',
#   'gps': '23.17287 120.32117',
#   'Level': '招呼',
#   'Link': '/wiki/%E6%8B%94%E6%9E%97%E8%BB%8A%E7%AB%99',
#   'Open': '1901-12-16',
#   'Line': '縱貫線'},
#  {'stationCode': 4170,
#   'stationName': '善化',
#   'stationEName': 'Shanhua',
#   'stationAddrTw': '臺南市善化區光文里中山路 1 號',
#   'stationAddrEn': 'No. 1, Zhongshan Rd., Shanhua Dist., Tainan City',
#   'stationTel': '06-5837301',
#   'gps': '23.13333 120.30653',
#   'Level': '二等',
#   'Link': '/wiki/%E5%96%84%E5%8C%96%E8%BB%8A%E7%AB%99',
#   'Open': '1901-05-15',
#   'Line': '縱貫線'},
#  {'stationCode': 4180,
#   'stationName': '南科',
#   'stationEName': 'Nanke',
#   'stationAddrTw': '臺南市新市區大營里大營 287-300 號',
#   'stationAddrEn': 'No. 287-300, Daying, Xinshi Dist., Tainan City',
#   'stationTel': '06-5896356',
#   'gps': '23.10714 120.30175',
#   'Level': '簡易',
#   'Link': '/wiki/%E5%8D%97%E7%A7%91%E8%BB%8A%E7%AB%99',
#   'Open': '2010-07-14',
#   'Line': '縱貫線'},
#  {'stationCode': 4190,
#   'stationName': '新市',
#   'stationEName': 'Xinshi',
#   'stationAddrTw': '臺南市新市區新和里中華路 1 號',
#   'stationAddrEn': 'No. 1, Zhonghua Rd., Xinshi Dist., Tainan City',
#   'stationTel': '06-5996911',
#   'gps': '23.06816 120.29004',
#   'Level': '三等',
#   'Link': '/wiki/%E6%96%B0%E5%B8%82%E8%BB%8A%E7%AB%99',
#   'Open': '1901-05-15',
#   'Line': '縱貫線'},
#  {'stationCode': 4200,
#   'stationName': '永康',
#   'stationEName': 'Yongkang',
#   'stationAddrTw': '臺南市永康區埔園里中山路 459 號',
#   'stationAddrEn': 'No. 459, Zhongshan Rd., Yongkang Dist., Tainan City',
#   'stationTel': '06-2323305',
#   'gps': '23.03873 120.25374',
#   'Level': '二等',
#   'Link': '/wiki/%E6%B0%B8%E5%BA%B7%E8%BB%8A%E7%AB%99',
#   'Open': '1903-03-10',
#   'Line': '縱貫線'},
#  {'stationCode': 4210,
#   'stationName': '大橋',
#   'stationEName': 'Daqiao',
#   'stationAddrTw': '臺南市永康區西橋里中華路 835 號',
#   'stationAddrEn': 'No. 835, Zhonghua Rd., Yongkang Dist., Tainan City',
#   'stationTel': '06-3021755',
#   'gps': '23.01951 120.22449',
#   'Level': '簡易',
#   'Link': '/wiki/%E5%A4%A7%E6%A9%8B%E8%BB%8A%E7%AB%99',
#   'Open': '2002-10-04',
#   'Line': '縱貫線'},
#  {'stationCode': 4220,
#   'stationName': '臺南',
#   'stationEName': 'Tainan',
#   'stationAddrTw': '臺南市東區成大里北門路二段 4 號',
#   'stationAddrEn': 'No. 4, Sec. 2, Beimen Rd., East Dist., Tainan City',
#   'stationTel': '06-2261314',
#   'gps': '22.99719 120.21231',
#   'Level': '一等',
#   'Link': '/wiki/%E8%87%BA%E5%8D%97%E8%BB%8A%E7%AB%99',
#   'Open': '1900-05-15',
#   'Line': '縱貫線、捷運：臺南捷運綠線'},
#  {'stationCode': 4250,
#   'stationName': '保安',
#   'stationEName': "Bao'an",
#   'stationAddrTw': '臺南市仁德區保安里文賢路一段 529 巷 10 號',
#   'stationAddrEn': 'No. 10, Ln. 529, Sec. 1, Wenxian Rd., Rende Dist., Tainan City',
#   'stationTel': '06-2665988',
#   'gps': '22.93289 120.23143',
#   'Level': '三等',
#   'Link': '/wiki/%E4%BF%9D%E5%AE%89%E8%BB%8A%E7%AB%99',
#   'Open': '1900-11-29',
#   'Line': '縱貫線'},
#  {'stationCode': 4260,
#   'stationName': '仁德',
#   'stationEName': 'Rende',
#   'stationAddrTw': '臺南市仁德區保安里永德路 10 號',
#   'stationAddrEn': 'No. 10, Yongde Rd., Rende Dist., Tainan City',
#   'stationTel': '06-2669383',
#   'gps': '22.92364 120.24061',
#   'Level': '簡易',
#   'Link': '/wiki/%E4%BB%81%E5%BE%B7%E8%BB%8A%E7%AB%99',
#   'Open': '2014-01-10',
#   'Line': '縱貫線'},
#  {'stationCode': 4270,
#   'stationName': '中洲',
#   'stationEName': 'Zhongzhou',
#   'stationAddrTw': '臺南市仁德區中洲五街236號',
#   'stationAddrEn': 'No. 236, Zhongzhou 5th St., Rende Dist., Tainan City',
#   'stationTel': '06-2667191',
#   'gps': '22.90466 120.25286',
#   'Level': '二等',
#   'Link': '/wiki/%E4%B8%AD%E6%B4%B2%E8%BB%8A%E7%AB%99',
#   'Open': '1901-12-11',
#   'Line': '縱貫線、沙崙線'},
#  {'stationCode': 4271,
#   'stationName': '長榮大學',
#   'stationEName': 'Chang Jung Christian University',
#   'stationAddrTw': '臺南市歸仁區大潭里長大路15 號',
#   'stationAddrEn': 'No. 15, Changda Rd., Guiren Dist., Tainan City',
#   'stationTel': '06-2782615',
#   'gps': '22.90735 120.27274',
#   'Level': '簡易',
#   'Link': '/wiki/%E9%95%B7%E6%A6%AE%E5%A4%A7%E5%AD%B8%E8%BB%8A%E7%AB%99',
#   'Open': '2011-01-02',
#   'Line': '沙崙線'},
#  {'stationCode': 4272,
#   'stationName': '沙崙',
#   'stationEName': 'Shalun',
#   'stationAddrTw': '臺南市歸仁區沙崙里歸仁大道 102 號',
#   'stationAddrEn': 'No. 102, Guiren Blvd., Guiren Dist., Tainan City',
#   'stationTel': '06-3032686',
#   'gps': '22.92419 120.28635',
#   'Level': '乙簡',
#   'Link': '/wiki/%E6%B2%99%E5%B4%99%E8%BB%8A%E7%AB%99',
#   'Open': '2011-01-02',
#   'Line': '沙崙線'},
#  {'stationCode': 4290,
#   'stationName': '大湖',
#   'stationEName': 'Dahu',
#   'stationAddrTw': '高雄市路竹區甲南里天祐路 24 號',
#   'stationAddrEn': 'No. 24, Tianyou Rd., Luzhu Dist., Kaohsiung City',
#   'stationTel': '07-6932127',
#   'gps': '22.87821 120.25384',
#   'Level': '三等',
#   'Link': '/wiki/%E5%A4%A7%E6%B9%96%E8%BB%8A%E7%AB%99_(%E5%8F%B0%E9%90%B5)',
#   'Open': '1900-11-29',
#   'Line': '縱貫線'},
#  {'stationCode': 4300,
#   'stationName': '路竹',
#   'stationEName': 'Luzhu',
#   'stationAddrTw': '高雄市路竹區竹南里中正路 288 號',
#   'stationAddrEn': 'No. 288, Zhongzheng Rd., Luzhu Dist., Kaohsiung City',
#   'stationTel': '07-6072723',
#   'gps': '22.85404 120.26619',
#   'Level': '三等',
#   'Link': '/wiki/%E8%B7%AF%E7%AB%B9%E8%BB%8A%E7%AB%99',
#   'Open': '1902-12-15',
#   'Line': '縱貫線'},
#  {'stationCode': 4310,
#   'stationName': '岡山',
#   'stationEName': 'Gangshan',
#   'stationAddrTw': '高雄市岡山區碧紅里岡燕路 111 號',
#   'stationAddrEn': 'No. 111, Gangyan Rd., Gangshan Dist., Kaohsiung City',
# ...
#   'stationEName': 'Xincheng',
#   'stationAddrTw': '花蓮縣新城鄉新城村新興一路 73 號',
#   'stationAddrEn': 'No. 73, Xinxing 1st Rd., Xincheng Township, Hualien County',
#   'stationTel': '03-8611237',
#   'gps': '24.12761 121.64103',
#   'Level': '二等',
#   'Link': '/wiki/%E6%96%B0%E5%9F%8E%EF%BC%88%E5%A4%AA%E9%AD%AF%E9%96%A3%EF%BC%89%E8%BB%8A%E7%AB%99',
#   'Open': '1975-07-26',
#   'Line': '北迴線'},
#  {'stationCode': 7040,
#   'stationName': '崇德',
#   'stationEName': 'Chongde',
#   'stationAddrTw': '花蓮縣秀林鄉崇德村海濱路 96 號',
#   'stationAddrEn': 'No. 96, Haibin Rd., Xiulin Township, Hualien County',
#   'stationTel': '03-8621365',
#   'gps': '24.17111 121.65555',
#   'Level': '三等',
#   'Link': '/wiki/%E5%B4%87%E5%BE%B7%E8%BB%8A%E7%AB%99',
#   'Open': '1979-02-08',
#   'Line': '北迴線'},
#  {'stationCode': 7050,
#   'stationName': '和仁',
#   'stationEName': 'Heren',
#   'stationAddrTw': '花蓮縣秀林鄉和平村和仁 71 號',
#   'stationAddrEn': 'No. 71, Heren, Xiulin Township, Hualien County',
#   'stationTel': '03-8681221',
#   'gps': '24.24219 121.71192',
#   'Level': '三等',
#   'Link': '/wiki/%E5%92%8C%E4%BB%81%E8%BB%8A%E7%AB%99',
#   'Open': '1979-02-08',
#   'Line': '北迴線'},
#  {'stationCode': 7060,
#   'stationName': '和平',
#   'stationEName': 'Heping',
#   'stationAddrTw': '花蓮縣秀林鄉和平村和平 276 號',
#   'stationAddrEn': 'No. 276, Heping, Xiulin Township, Hualien County',
#   'stationTel': '03-8681009',
#   'gps': '24.29825 121.75322',
#   'Level': '二等',
#   'Link': '/wiki/%E5%92%8C%E5%B9%B3%E8%BB%8A%E7%AB%99_(%E8%8A%B1%E8%93%AE%E7%B8%A3)',
#   'Open': '1979-02-08',
#   'Line': '北迴線'},
#  {'stationCode': 7070,
#   'stationName': '漢本',
#   'stationEName': 'Hanben',
#   'stationAddrTw': '宜蘭縣南澳鄉澳花村蘇花路一段 56 號',
#   'stationAddrEn': 'No. 56, Sec. 1, Suhua Rd., Nan`ao Township, Yilan County',
#   'stationTel': '03-9985238',
#   'gps': '24.33561 121.76878',
#   'Level': '三等',
#   'Link': '/wiki/%E6%BC%A2%E6%9C%AC%E8%BB%8A%E7%AB%99',
#   'Open': '1980-02-01',
#   'Line': '北迴線'},
#  {'stationCode': 7080,
#   'stationName': '武塔',
#   'stationEName': 'Wuta',
#   'stationAddrTw': '宜蘭縣南澳鄉武塔村新溪路 18 號',
#   'stationAddrEn': 'No. 18, Xinxi Rd., Nan`ao Township, Yilan County',
#   'stationTel': '03-9981971',
#   'gps': '24.44879 121.77601',
#   'Level': '乙簡',
#   'Link': '/wiki/%E6%AD%A6%E5%A1%94%E8%BB%8A%E7%AB%99',
#   'Open': '1980-02-01',
#   'Line': '北迴線'},
#  {'stationCode': 7090,
#   'stationName': '南澳',
#   'stationEName': "Nan'ao",
#   'stationAddrTw': '宜蘭縣蘇澳鎮南強里大通路 22 號',
#   'stationAddrEn': 'No. 22, Datong Rd., Su`ao Township, Yilan County',
#   'stationTel': '03-9981971',
#   'gps': '24.46342 121.80103',
#   'Level': '三等',
#   'Link': '/wiki/%E5%8D%97%E6%BE%B3%E8%BB%8A%E7%AB%99',
#   'Open': '1980-02-01',
#   'Line': '北迴線'},
#  {'stationCode': 7100,
#   'stationName': '東澳',
#   'stationEName': "Dong'ao",
#   'stationAddrTw': '宜蘭縣南澳鄉東岳村東岳路 1 號',
#   'stationAddrEn': 'No. 1, Dongyue Rd., Nan`ao Township, Yilan County',
#   'stationTel': '03-9986053',
#   'gps': '24.51828 121.83071',
#   'Level': '二等',
#   'Link': '/wiki/%E6%9D%B1%E6%BE%B3%E8%BB%8A%E7%AB%99',
#   'Open': '1980-02-01',
#   'Line': '北迴線'},
#  {'stationCode': 7110,
#   'stationName': '永樂',
#   'stationEName': 'Yongle',
#   'stationAddrTw': '宜蘭縣蘇澳鎮永樂里圳頭路 60 號',
#   'stationAddrEn': 'No. 60, Zuntou Rd., Su`ao Township, Yilan County',
#   'stationTel': '03-9961889',
#   'gps': '24.56843 121.84458',
#   'Level': '三等',
#   'Link': '/wiki/%E6%B0%B8%E6%A8%82%E8%BB%8A%E7%AB%99_(%E5%AE%9C%E8%98%AD%E7%B8%A3)',
#   'Open': '1980-02-01',
#   'Line': '北迴線'},
#  {'stationCode': 7120,
#   'stationName': '蘇澳',
#   'stationEName': "Su'ao",
#   'stationAddrTw': '宜蘭縣蘇澳鎮蘇南里太平路 1 號',
#   'stationAddrEn': 'No. 1, Taiping Rd., Su`ao Township, Yilan County',
#   'stationTel': '03-9962028',
#   'gps': '24.59521 121.85144',
#   'Level': '二等',
#   'Link': '/wiki/%E8%98%87%E6%BE%B3%E8%BB%8A%E7%AB%99',
#   'Open': '1919-03-24',
#   'Line': '宜蘭線'},
#  {'stationCode': 7130,
#   'stationName': '蘇澳新',
#   'stationEName': "Su'aoxin",
#   'stationAddrTw': '宜蘭縣蘇澳鎮聖愛里中山路二段 238 之 1 號',
#   'stationAddrEn': 'No. 238-1, Sec. 2, Zhongshan Rd., Su`ao Township, Yilan County',
#   'stationTel': '03-9961004',
#   'gps': '24.60852 121.82719',
#   'Level': '一等',
#   'Link': '/wiki/%E8%98%87%E6%BE%B3%E6%96%B0%E7%AB%99',
#   'Open': '1968-04-15',
#   'Line': '宜蘭線、北迴線'},
#  {'stationCode': 7140,
#   'stationName': '新馬',
#   'stationEName': 'Xinma',
#   'stationAddrTw': '宜蘭縣蘇澳鎮新城里中山路二段 322 號',
#   'stationAddrEn': 'No. 322, Sec. 2, Zhongshan Rd., Su`ao Township, Yilan County',
#   'stationTel': '03-9961004',
#   'gps': '24.61535 121.82292',
#   'Level': '招呼',
#   'Link': '/wiki/%E6%96%B0%E9%A6%AC%E8%BB%8A%E7%AB%99',
#   'Open': '1920-11-22',
#   'Line': '宜蘭線'},
#  {'stationCode': 7150,
#   'stationName': '冬山',
#   'stationEName': 'Dongshan',
#   'stationAddrTw': '宜蘭縣冬山鄉冬山村中正路 1 號',
#   'stationAddrEn': 'No. 1, Zhongzheng Rd., Dongshan Township, Yilan County',
#   'stationTel': '03-9594221',
#   'gps': '24.63627 121.79212',
#   'Level': '三等',
#   'Link': '/wiki/%E5%86%AC%E5%B1%B1%E8%BB%8A%E7%AB%99',
#   'Open': '1919-03-24',
#   'Line': '宜蘭線'},
#  {'stationCode': 7160,
#   'stationName': '羅東',
#   'stationEName': 'Luodong',
#   'stationAddrTw': '宜蘭縣羅東鎮大新里公正路 2 號',
#   'stationAddrEn': 'No. 2, Gongzheng Rd., Luodong Township, Yilan County',
#   'stationTel': '03-9542117',
#   'gps': '24.67795 121.77424',
#   'Level': '二等',
#   'Link': '/wiki/%E7%BE%85%E6%9D%B1%E8%BB%8A%E7%AB%99',
#   'Open': '1919-03-24',
#   'Line': '宜蘭線'},
#  {'stationCode': 7170,
#   'stationName': '中里',
#   'stationEName': 'Zhongli_Yilan',
#   'stationAddrTw': '宜蘭縣五結鄉中興村台興路 10 號',
#   'stationAddrEn': 'No. 10, Taixing Rd., Wujie Township, Yilan County',
#   'stationTel': '03-9542117',
#   'gps': '24.69415 121.77526',
#   'Level': '招呼',
#   'Link': '/wiki/%E4%B8%AD%E9%87%8C%E8%BB%8A%E7%AB%99',
#   'Open': '1936-07-20',
#   'Line': '宜蘭線'},
#  {'stationCode': 7180,
#   'stationName': '二結',
#   'stationEName': 'Erjie',
#   'stationAddrTw': '宜蘭縣五結鄉五結中路三段658巷8號',
#   'stationAddrEn': 'No. 8,Lane 658,WuJie Central Rd. Sec.3, Wujie Township, Yilan County',
#   'stationTel': '03-9650304',
#   'gps': '24.70529 121.77411',
#   'Level': '三等',
#   'Link': '/wiki/%E4%BA%8C%E7%B5%90%E8%BB%8A%E7%AB%99',
#   'Open': '1919-03-24',
#   'Line': '宜蘭線'},
#  {'stationCode': 7190,
#   'stationName': '宜蘭',
#   'stationEName': 'Yilan',
#   'stationAddrTw': '宜蘭縣宜蘭市和睦里光復路 1 號',
#   'stationAddrEn': 'No. 1, Guangfu Rd., Yilan City, Yilan County',
#   'stationTel': '03-9323801',
#   'gps': '24.75462 121.75791',
#   'Level': '一等',
#   'Link': '/wiki/%E5%AE%9C%E8%98%AD%E8%BB%8A%E7%AB%99',
#   'Open': '1919-03-24',
#   'Line': '宜蘭線'},
#  {'stationCode': 7200,
#   'stationName': '四城',
#   'stationEName': 'Sicheng',
#   'stationAddrTw': '宜蘭縣礁溪鄉吳沙村站前路 24 號',
#   'stationAddrEn': 'No. 24, Zhanqian Rd., Jiaoxi Township, Yilan County',
#   'stationTel': '03-9282449',
#   'gps': '24.78684 121.76268',
#   'Level': '甲簡',
#   'Link': '/wiki/%E5%9B%9B%E5%9F%8E%E8%BB%8A%E7%AB%99',
#   'Open': '1921-02-25',
#   'Line': '宜蘭線'},
#  {'stationCode': 7210,
#   'stationName': '礁溪',
#   'stationEName': 'Jiaoxi',
#   'stationAddrTw': '宜蘭縣礁溪鄉德陽村溫泉路 1 號',
#   'stationAddrEn': 'No. 1, Wenquan Rd., Jiaoxi Township, Yilan County',
#   'stationTel': '03-9886940',
#   'gps': '24.82705 121.77523',
#   'Level': '三等',
#   'Link': '/wiki/%E7%A4%81%E6%BA%AA%E8%BB%8A%E7%AB%99',
#   'Open': '1919-11-15',
#   'Line': '宜蘭線'},
#  {'stationCode': 7220,
#   'stationName': '頂埔',
#   'stationEName': 'Dingpu',
#   'stationAddrTw': '宜蘭縣頭城鎮下埔里下埔路 4 之 8 號',
#   'stationAddrEn': 'No. 4-8, Xiapu Rd., Toucheng Township, Yilan County',
#   'stationTel': '03-9886940',
#   'gps': '24.84383 121.80918',
#   'Level': '招呼',
#   'Link': '/wiki/%E9%A0%82%E5%9F%94%E8%BB%8A%E7%AB%99_(%E5%AE%9C%E8%98%AD%E7%B8%A3)',
#   'Open': '1937-05-01',
#   'Line': '宜蘭線'},
#  {'stationCode': 7230,
#   'stationName': '頭城',
#   'stationEName': 'Toucheng',
#   'stationAddrTw': '宜蘭縣頭城鎮纘祥路 59 號',
#   'stationAddrEn': 'No. 59, Zuanxiang Rd., Toucheng Township, Yilan County',
#   'stationTel': '03-9771429',
#   'gps': '24.85898 121.82253',
#   'Level': '二等',
#   'Link': '/wiki/%E9%A0%AD%E5%9F%8E%E8%BB%8A%E7%AB%99',
#   'Open': '1920-04-25',
#   'Line': '宜蘭線'},
#  {'stationCode': 7240,
#   'stationName': '外澳',
#   'stationEName': "Wai'ao",
#   'stationAddrTw': '宜蘭縣頭城鎮濱海路二段 217 號',
#   'stationAddrEn': 'No. 217, Sec. 2, Binhai Rd., Toucheng Township, Yilan County',
#   'stationTel': '03-9771429',
#   'gps': '24.88371 121.84576',
#   'Level': '招呼',
#   'Link': '/wiki/%E5%A4%96%E6%BE%B3%E8%BB%8A%E7%AB%99',
#   'Open': '1920-12-10',
#   'Line': '宜蘭線'},
#  {'stationCode': 7250,
#   'stationName': '龜山',
#   'stationEName': 'Guishan',
#   'stationAddrTw': '宜蘭縣頭城鎮更新里濱海路三段 261 號',
#   'stationAddrEn': 'No. 261, Sec. 3, Binhai Rd., Toucheng Township, Yilan County',
#   'stationTel': '03-9770351',
#   'gps': '24.90481 121.86886',
#   'Level': '甲簡',
#   'Link': '/wiki/%E9%BE%9C%E5%B1%B1%E8%BB%8A%E7%AB%99_(%E5%8F%B0%E7%81%A3)',
#   'Open': '1920-12-10',
#   'Line': '宜蘭線'},
#  {'stationCode': 7260,
#   'stationName': '大溪',
#   'stationEName': 'Daxi',
#   'stationAddrTw': '宜蘭縣頭城鎮濱海路五段 63 號',
#   'stationAddrEn': 'No. 63, Sec. 5, Binhai Rd., Toucheng Township, Yilan County',
#   'stationTel': '03-9771429',
#   'gps': '24.93836 121.88983',
#   'Level': '簡易',
#   'Link': '/wiki/%E5%A4%A7%E6%BA%AA%E8%BB%8A%E7%AB%99',
#   'Open': '1920-12-10',
#   'Line': '宜蘭線'},
#  {'stationCode': 7270,
#   'stationName': '大里',
#   'stationEName': 'Dali',
#   'stationAddrTw': '宜蘭縣頭城鎮大里里濱海路六段 326 號',
#   'stationAddrEn': 'No. 326, Sec. 6, Binhai Rd., Toucheng Township, Yilan County',
#   'stationTel': '03-9781171',
#   'gps': '24.96688 121.92257',
#   'Level': '甲簡',
#   'Link': '/wiki/%E5%A4%A7%E9%87%8C%E8%BB%8A%E7%AB%99',
#   'Open': '1920-12-10',
#   'Line': '宜蘭線'},
#  {'stationCode': 7280,
#   'stationName': '石城',
#   'stationEName': 'Shicheng',
#   'stationAddrTw': '宜蘭縣頭城鎮濱海路七段 230 號',
#   'stationAddrEn': 'No. 230, Sec. 7, Binhai Rd., Toucheng Township, Yilan County',
#   'stationTel': '03-9771429',
#   'gps': '24.97837 121.94546',
#   'Level': '招呼',
#   'Link': '/wiki/%E7%9F%B3%E5%9F%8E%E8%BB%8A%E7%AB%99',
#   'Open': '1953-05-01',
#   'Line': '宜蘭線'},
#  {'stationCode': 7290,
#   'stationName': '福隆',
#   'stationEName': 'Fulong',
#   'stationAddrTw': '新北市貢寮區福隆里福隆街 2 號',
#   'stationAddrEn': 'No. 2, Fulong St., Gongliao Dist., New Taipei City',
#   'stationTel': '02-24991800',
#   'gps': '25.01598 121.94471',
#   'Level': '三等',
#   'Link': '/wiki/%E7%A6%8F%E9%9A%86%E8%BB%8A%E7%AB%99',
#   'Open': '1924-12-01',
#   'Line': '宜蘭線'},
#  {'stationCode': 7300,
#   'stationName': '貢寮',
#   'stationEName': 'Gongliao',
#   'stationAddrTw': '新北市貢寮區貢寮里朝陽街 33 號',
#   'stationAddrEn': 'No. 33, Chaoyang St., Gongliao Dist., New Taipei City',
#   'stationTel': '02-24941500',
#   'gps': '25.02209 121.90867',
#   'Level': '甲簡',
#   'Link': '/wiki/%E8%B2%A2%E5%AF%AE%E8%BB%8A%E7%AB%99',
#   'Open': '1924-12-01',
#   'Line': '宜蘭線'},
#  {'stationCode': 7310,
#   'stationName': '雙溪',
#   'stationEName': 'Shuangxi',
#   'stationAddrTw': '新北市雙溪區新基里朝陽街 1 號',
#   'stationAddrEn': 'No. 1, Chaoyang St., Shuangxi Dist., New Taipei City',
#   'stationTel': '02-24932980',
#   'gps': '25.03858 121.86645',
#   'Level': '二等',
#   'Link': '/wiki/%E9%9B%99%E6%BA%AA%E8%BB%8A%E7%AB%99',
#   'Open': '1923-10-11',
#   'Line': '宜蘭線'},
#  {'stationCode': 7320,
#   'stationName': '牡丹',
#   'stationEName': 'Mudan',
#   'stationAddrTw': '新北市雙溪區牡丹里51號',
#   'stationAddrEn': 'No. 159, Mudan Rd., Shuangxi Dist., New Taipei City',
#   'stationTel': '02-24932980',
#   'gps': '25.05877 121.85194',
#   'Level': '簡易',
#   'Link': '/wiki/%E7%89%A1%E4%B8%B9%E8%BB%8A%E7%AB%99',
#   'Open': '1922-09-13',
#   'Line': '宜蘭線'},
#  {'stationCode': 7330,
#   'stationName': '三貂嶺',
#   'stationEName': 'Sandiaoling',
#   'stationAddrTw': '新北市瑞芳區碩仁里魚寮路 1 號',
#   'stationAddrEn': 'No. 1, Yuliao Rd., Ruifang Dist., New Taipei City',
#   'stationTel': '02-24977896',
#   'gps': '25.06555 121.82259',
#   'Level': '三等',
#   'Link': '/wiki/%E4%B8%89%E8%B2%82%E5%B6%BA%E8%BB%8A%E7%AB%99',
#   'Open': '1922-05-16',
#   'Line': '宜蘭線、平溪線'},
#  {'stationCode': 7331,
#   'stationName': '大華',
#   'stationEName': 'Dahua',
#   'stationAddrTw': '新北市平溪區南山里六分 12 之 1 號',
#   'stationAddrEn': 'No. 12-1, Liufen, Pingxi Dist., New Taipei City',
#   'stationTel': '02-24972033',
#   'gps': '25.04993 121.79751',
#   'Level': '招呼',
#   'Link': '/wiki/%E5%A4%A7%E8%8F%AF%E8%BB%8A%E7%AB%99',
#   'Open': '1956-10-12',
#   'Line': '平溪線'},
#  {'stationCode': 7332,
#   'stationName': '十分',
#   'stationEName': 'Shifen',
#   'stationAddrTw': '新北市平溪區十分里十分街 51 號',
#   'stationAddrEn': 'No. 51, Shifen St., Pingxi Dist., New Taipei City',
#   'stationTel': '02-24958307',
#   'gps': '25.04111 121.77514',
#   'Level': '丙簡',
#   'Link': '/wiki/%E5%8D%81%E5%88%86%E8%BB%8A%E7%AB%99',
#   'Open': '1929-10-01',
#   'Line': '平溪線'},
#  {'stationCode': 7333,
#   'stationName': '望古',
#   'stationEName': 'Wanggu',
#   'stationAddrTw': '新北市平溪區望古里 (無站房)',
#   'stationAddrEn': 'Wanggu Vil. (No Station Building), Pingxi Dist., New Taipei City',
#   'stationTel': '02-24972033',
#   'gps': '25.03445 121.76349',
#   'Level': '招呼',
#   'Link': '/wiki/%E6%9C%9B%E5%8F%A4%E8%BB%8A%E7%AB%99',
#   'Open': '1972-07-30',
#   'Line': '平溪線'},
#  {'stationCode': 7334,
#   'stationName': '嶺腳',
#   'stationEName': 'Lingjiao',
#   'stationAddrTw': '新北市平溪區嶺腳里嶺腳寮 22 號',
#   'stationAddrEn': 'No. 22, Lingjiaoliao, Pingxi Dist., New Taipei City',
#   'stationTel': '02-24972033',
#   'gps': '25.03021 121.74784',
#   'Level': '招呼',
#   'Link': '/wiki/%E5%B6%BA%E8%85%B3%E8%BB%8A%E7%AB%99',
#   'Open': '1929-10-01',
#   'Line': '平溪線'},
#  {'stationCode': 7335,
#   'stationName': '平溪',
#   'stationEName': 'Pingxi',
#   'stationAddrTw': '新北市平溪區平溪里中華街 12 號',
#   'stationAddrEn': 'No. 12, Zhonghua St., Pingxi Dist., New Taipei City',
#   'stationTel': '02-24972033',
#   'gps': '25.02552 121.73994',
#   'Level': '簡易',
#   'Link': '/wiki/%E5%B9%B3%E6%BA%AA%E8%BB%8A%E7%AB%99',
#   'Open': '1929-10-01',
#   'Line': '平溪線'},
#  {'stationCode': 7336,
#   'stationName': '菁桐',
#   'stationEName': 'Jingtong',
#   'stationAddrTw': '新北市平溪區菁桐里菁桐街 52 號',
#   'stationAddrEn': 'No. 52, Jingtong St., Pingxi Dist., New Taipei City',
#   'stationTel': '02-24972033',
#   'gps': '25.02384 121.72394',
#   'Level': '簡易',
#   'Link': '/wiki/%E8%8F%81%E6%A1%90%E8%BB%8A%E7%AB%99',
#   'Open': '1929-10-01',
#   'Line': '平溪線'},
#  {'stationCode': 7350,
#   'stationName': '猴硐',
#   'stationEName': 'Houtong',
#   'stationAddrTw': '新北市瑞芳區光復里柴寮路 70 號',
#   'stationAddrEn': 'No. 70, Chailiao Rd., Ruifang Dist., New Taipei City',
#   'stationTel': '02-24977747',
#   'gps': '25.08711 121.82741',
#   'Level': '三等',
#   'Link': '/wiki/%E7%8C%B4%E7%A1%90%E8%BB%8A%E7%AB%99',
#   'Open': '1920-01-27',
#   'Line': '宜蘭線'},
#  {'stationCode': 7360,
#   'stationName': '瑞芳',
#   'stationEName': 'Ruifang',
#   'stationAddrTw': '新北市瑞芳區龍潭里明燈路三段 82 號',
#   'stationAddrEn': 'No. 82, Sec. 3, Mingdeng Rd., Ruifang Dist., New Taipei City',
#   'stationTel': '02-24972033',
#   'gps': '25.10861 121.80596',
#   'Level': '一等',
#   'Link': '/wiki/%E7%91%9E%E8%8A%B3%E7%AB%99',
#   'Open': '1919-05-05',
#   'Line': '宜蘭線、深澳線'},
#  {'stationCode': 7361,
#   'stationName': '海科館',
#   'stationEName': 'Haikeguan',
#   'stationAddrTw': '基隆市中正區長潭里',
#   'stationAddrEn': 'Changtan Vil., Zhongzheng Dist., Keelung City',
#   'stationTel': '02-24972033',
#   'gps': '25.13768 121.80003',
#   'Level': '招呼',
#   'Link': '/wiki/%E6%B5%B7%E7%A7%91%E9%A4%A8%E7%AB%99',
#   'Open': '2014-01-09',
#   'Line': '深澳線'},
#  {'stationCode': 7362,
#   'stationName': '八斗子',
#   'stationEName': 'Badouzi',
#   'stationAddrTw': '基隆市中正區砂子里省道臺 2 線 (與新北市瑞芳區交界處、無站房)',
#   'stationAddrEn': 'Provincial Highway 2 (Junction of Ruifang Dist., New Taipei City, No Station Building), Zhongzheng Dist., Keelung City',
#   'stationTel': '02-24972033',
#   'gps': '25.13481 121.80411',
#   'Level': '招呼',
#   'Link': '/wiki/%E5%85%AB%E6%96%97%E5%AD%90%E7%AB%99',
#   'Open': '1967-08-25',
#   'Line': '深澳線'},
#  {'stationCode': 7380,
#   'stationName': '四腳亭',
#   'stationEName': 'Sijiaoting',
#   'stationAddrTw': '新北市瑞芳區吉慶里中央路 65 號',
#   'stationAddrEn': 'No. 65, Zhongyang Rd., Ruifang Dist., New Taipei City',
#   'stationTel': '02-24579346',
#   'gps': '25.10281 121.76192',
#   'Level': '三等',
#   'Link': '/wiki/%E5%9B%9B%E8%85%B3%E4%BA%AD%E8%BB%8A%E7%AB%99',
#   'Open': '1919-05-05',
#   'Line': '宜蘭線'},
#  {'stationCode': 7390,
#   'stationName': '暖暖',
#   'stationEName': 'Nuannuan',
#   'stationAddrTw': '基隆市暖暖區暖暖里暖暖街 51 號',
#   'stationAddrEn': 'No. 66, Nuannuan St., Nuannuan Dist., Keelung City',
#   'stationTel': '02-24972033',
#   'gps': '25.10224 121.74048',
#   'Level': '招呼',
#   'Link': '/wiki/%E6%9A%96%E6%9A%96%E8%BB%8A%E7%AB%99',
#   'Open': '1919-05-05',
#   'Line': '宜蘭線'}]
